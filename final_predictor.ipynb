# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, models
import torch.nn as nn
import torch.optim as optim
from PIL import Image
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Load an image for prediction (for example, from a file)
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
import cv2

import numpy as np
import mediapipe as mp

# %%
# === Load models ===
face_model = load_model("../models/face_direction_model2.h5")
eye_model = load_model("../models/eyes_dir_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# === Class labels ===
face_labels = ['left', 'right', 'front']
eye_labels = [
    "BottomCenter",
    "BottomLeft",
    "BottomRight",
    "MiddleLeft",
    "MiddleRight",
    "TopCenter",
    "TopLeft",
    "TopRight"
]

# %%
# === Parameters ===
img_path = "../Datasets/t2.jpg"  # Use the same image for both models
face_img = cv2.imread(img_path)
if face_img is None:
    raise FileNotFoundError(f"Image not found at path: {img_path}")
eye_img = face_img.copy()

face_img_size = (128, 128)
eye_img_size = (64, 64)

# === Face direction prediction ===
face_img_resized = cv2.resize(face_img, face_img_size)
face_img_resized = face_img_resized.astype('float32') / 255.0
face_img_array = np.expand_dims(face_img_resized, axis=0)

face_prediction = face_model.predict(face_img_array, verbose=0)[0]
left, right, front = face_prediction

# === Custom logic for face direction ===
diff_front_right = front - right


if (
    # If front is highest, but right is close enough, prefer right
    (front >= 0.25 and 0.01 <= diff_front_right <= 0.18)
    or
    # If right is clearly stronger than left
    (right > 0.5 and left < 0.25)
    or
    (right > 2 * left)
):
    predicted_face_dir = "right"
elif (left > right) or (left > 0.2 and right < 0.5):
    predicted_face_dir = "left"
else:
    predicted_face_dir = face_labels[np.argmax(face_prediction)]  # default to max


# === Eye detection and prediction ===
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True)
rgb_eye_img = cv2.cvtColor(eye_img, cv2.COLOR_BGR2RGB)

results = face_mesh.process(rgb_eye_img)
# === Fallback setup for Haar cascades ===
eye_detected = False
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")


h, w = eye_img.shape[:2]
left_eye_prediction = None
right_eye_prediction = None


def preprocess_eye(eye_roi):
    eye_gray = cv2.cvtColor(eye_roi, cv2.COLOR_BGR2GRAY)
    eye_resized = cv2.resize(eye_gray, eye_img_size)
    eye_array = eye_resized.astype("float32") / 255.0
    eye_array = np.expand_dims(eye_array, axis=[0, -1])
    return eye_array


def predict_eye(eye_array):
    prediction = eye_model.predict(eye_array, verbose=0)[0]
    idx = np.argmax(prediction)
    return eye_labels[idx], prediction[idx], prediction


if results.multi_face_landmarks:
    for face_landmarks in results.multi_face_landmarks:
        left_eye_idx = [33, 133]
        right_eye_idx = [362, 263]

        def extract_eye(indices):
            x = [int(face_landmarks.landmark[i].x * w) for i in indices]
            y = [int(face_landmarks.landmark[i].y * h) for i in indices]
            x1, x2 = min(x), max(x)
            y1, y2 = min(y), max(y)
            mx, my = int((x2 - x1) * 0.4), int((y2 - y1) * 1.2)
            return max(x1 - mx, 0), max(y1 - my, 0), min(x2 + mx, w), min(y2 + my, h)

        for label, indices in zip(["Left", "Right"], [left_eye_idx, right_eye_idx]):
            x1, y1, x2, y2 = extract_eye(indices)
            eye_roi = eye_img[y1:y2, x1:x2]
            if eye_roi.size == 0:
                continue
            eye_array = preprocess_eye(eye_roi)
            pred_label, prob, pred_vector = predict_eye(eye_array)
            cv2.rectangle(eye_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(eye_img, f"{label} Eye: {pred_label}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
            if label == "Left":
                left_eye_prediction = (pred_label, prob, pred_vector)
            else:
                right_eye_prediction = (pred_label, prob, pred_vector)
            eye_detected = True

else:
    # === Fallback: Haar Cascade eye detection ===
    print("⚠️ MediaPipe failed, using Haar Cascade fallback.")

    gray = cv2.cvtColor(eye_img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w_, h_) in faces:
        roi_gray = gray[y:y+h_, x:x+w_]
        roi_color = eye_img[y:y+h_, x:x+w_]
        eyes = eye_cascade.detectMultiScale(roi_gray)

        for i, (ex, ey, ew, eh) in enumerate(eyes[:2]):  # Limit to 2 eyes
            if ew < 10 or eh < 10 or ew > w_ // 2:
                continue

            eye_roi = roi_color[ey:ey+eh, ex:ex+ew]
            if eye_roi.size == 0:
                continue

            eye_array = preprocess_eye(eye_roi)
            pred_label, prob, pred_vector = predict_eye(eye_array)

            label = "Left" if i == 0 else "Right"
            cv2.putText(eye_img, f"{label} Eye: {pred_label}", (x + ex, y + ey - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 255), 2)

            if label == "Left":
                left_eye_prediction = (pred_label, prob, pred_vector)
            else:
                right_eye_prediction = (pred_label, prob, pred_vector)
            eye_detected = True






# === Final unified logic (revised) ===
# === Final unified logic (final adjusted version) ===
eye_final_label = None

if left_eye_prediction and right_eye_prediction:
    left_label = left_eye_prediction[0]
    right_label = right_eye_prediction[0]

    if left_label == right_label:
        eye_final_label = left_label
    else:
        # You can decide which one is more confident
        if left_eye_prediction[1] > right_eye_prediction[1]:
            eye_final_label = left_label
        else:
            eye_final_label = right_label
# === Final unified logic ===
final_direction = predicted_face_dir

if left_eye_prediction and right_eye_prediction:
    # Get the prediction vectors for both eyes
    left_vector = left_eye_prediction[2]
    right_vector = right_eye_prediction[2]

    # Define individual thresholds
    thresholds = {
        "TopCenter": 0.70,
        "BottomCenter": 0.98  # Less influence
    }

    for label, threshold in thresholds.items():
        idx = eye_labels.index(label)
        if left_vector[idx] > threshold or right_vector[idx] > threshold:
            final_direction = "front"
            break

# === Display results ===
cv2.putText(eye_img, f"Final Direction: {final_direction.upper()}", (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

cv2.imshow("Unified Gaze Output", eye_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# === Console logs ===
print("\n=== Face Direction Model Prediction Scores ===")
for i, label in enumerate(face_labels):
    print(f"{label}: {face_prediction[i]:.4f}")

print(f"\n→ Final Direction: {final_direction.upper()}")

if eye_final_label:
    print("\n=== Eye Model Decision ===")
    print(f"Left Eye: {left_eye_prediction[0]} ({left_eye_prediction[1]:.4f})")
    print(f"Right Eye: {right_eye_prediction[0]} ({right_eye_prediction[1]:.4f})")
    print(f"→ Synchronized Eye Label: {eye_final_label}")
# Out:
# === Face Direction Model Prediction Scores ===
# left: 0.2462
# right: 0.4121
# front: 0.3418
#
# → Final Direction: LEFT
#
# === Eye Model Decision ===
# Left Eye: MiddleRight (0.4245)
# Right Eye: MiddleRight (0.5853)
# → Synchronized Eye Label: MiddleRight

# %%
# === Parameters ===
img_path = "../Datasets/t5.jpg"  # Use the same image for both models
face_img = cv2.imread(img_path)
if face_img is None:
    raise FileNotFoundError(f"Image not found at path: {img_path}")
eye_img = face_img.copy()

face_img_size = (128, 128)
eye_img_size = (64, 64)

# === Face direction prediction ===
face_img_resized = cv2.resize(face_img, face_img_size)
face_img_resized = face_img_resized.astype('float32') / 255.0
face_img_array = np.expand_dims(face_img_resized, axis=0)

face_prediction = face_model.predict(face_img_array, verbose=0)[0]
left, right, front = face_prediction

# === Custom logic for face direction ===
diff_front_right = front - right


if (
    # If front is highest, but right is close enough, prefer right
    (front >= 0.25 and 0.01 <= diff_front_right <= 0.2)
    or
    # If right is clearly stronger than left
    (right > 0.5 and left < 0.25)
    or
    (right > 2 * left)
):
    predicted_face_dir = "right"
elif (left > right) or (left > 0.2 and right < 0.5):
    predicted_face_dir = "left"
else:
    predicted_face_dir = face_labels[np.argmax(face_prediction)]  # default to max



# === Read input image ===
img = eye_img  # <-- Change as needed
if img is None:
    raise ValueError("Image not found!")


# === Load trained model ===
model = eye_model
img_size = eye_img_size

# === Class labels ===
class_labels = eye_labels  # <-- Dynamically picked

# === Initialize MediaPipe face mesh ===
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True)

# === Load Haar cascades (fallback if MediaPipe fails) ===
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# Resize if too large
max_width, max_height = 800, 600
h, w = img.shape[:2]
if w > max_width or h > max_height:
    scale = min(max_width / w, max_height / h)
    img = cv2.resize(img, (int(w * scale), int(h * scale)))
    h, w = img.shape[:2]

# Convert to RGB
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
results = face_mesh.process(rgb_img)

# Flag to check if MediaPipe worked
eye_detected = False

# === Helper functions ===
def preprocess_eye(eye_roi):
    eye_gray = cv2.cvtColor(eye_roi, cv2.COLOR_BGR2GRAY)
    eye_resized = cv2.resize(eye_gray, img_size)
    eye_array = eye_resized.astype("float32") / 255.0
    eye_array = np.expand_dims(eye_array, axis=[0, -1])  # (1, 64, 64, 1)
    return eye_array

def predict_eye(eye_array):
    prediction = model.predict(eye_array, verbose=0)[0]
    predicted_idx = np.argmax(prediction)
    return class_labels[predicted_idx], prediction[predicted_idx], prediction

def print_probs(prediction, class_labels):
    print("Probabilities:")
    for label, prob in zip(class_labels, prediction):
        print(f"  {label}: {prob:.4f}")
    predicted_idx = np.argmax(prediction)
    return class_labels[predicted_idx], prediction[predicted_idx]

# === Try MediaPipe face mesh first ===
if results.multi_face_landmarks:
    for face_landmarks in results.multi_face_landmarks:
        left_eye_indices = [33, 133]
        right_eye_indices = [362, 263]

        def extract_eye_region(indices):
            x_coords = [int(face_landmarks.landmark[i].x * w) for i in indices]
            y_coords = [int(face_landmarks.landmark[i].y * h) for i in indices]
            x_min, x_max = min(x_coords), max(x_coords)
            y_min, y_max = min(y_coords), max(y_coords)
            margin_x = int((x_max - x_min) * 0.4)
            margin_y = int((y_max - y_min) * 1.2)
            x1 = max(x_min - margin_x, 0)
            y1 = max(y_min - margin_y, 0)
            x2 = min(x_max + margin_x, w)
            y2 = min(y_max + margin_y, h)
            return x1, y1, x2, y2

        left_pred = right_pred = None

        for eye_label, indices in zip(["Left", "Right"], [left_eye_indices, right_eye_indices]):
            x1, y1, x2, y2 = extract_eye_region(indices)
            eye_roi = img[y1:y2, x1:x2]
            if eye_roi.size == 0:
                continue

            eye_array = preprocess_eye(eye_roi)
            predicted_label, predicted_prob, prediction = predict_eye(eye_array)

            if eye_label == "Left":
                left_pred = (predicted_label, predicted_prob, prediction)
            else:
                right_pred = (predicted_label, predicted_prob, prediction)

            label_text = f"{eye_label}: {predicted_label} ({predicted_prob:.2f})"
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.rectangle(eye_img, (x1, y1), (x2, y2), (0, 255, 0), 2)

            cv2.putText(img, label_text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

            print(f"[{eye_label} Eye] {label_text}")
            print_probs(prediction, class_labels)
            eye_detected = True

        if left_pred and right_pred:
            # After MediaPipe (inside if left_pred and right_pred:) 
            left_eye_prediction = left_pred
            right_eye_prediction = right_pred

            

           

# === Fallback to Haar cascades ===
if not eye_detected:
    print("⚠️ MediaPipe failed, using Haar cascades...")
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)

        predictions = []

        for i, (ex, ey, ew, eh) in enumerate(eyes[:2]):
            if ew < 10 or eh < 10 or ey > h // 2:
                continue

            eye_roi = roi_color[ey:ey+eh, ex:ex+ew]
            if eye_roi.size == 0:
                continue

            eye_array = preprocess_eye(eye_roi)
            predicted_label, predicted_prob, prediction = predict_eye(eye_array)
            predictions.append((predicted_label, predicted_prob, prediction))

            label_text = f"Eye{i+1}: {predicted_label} ({predicted_prob:.2f})"
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (255, 0, 0), 2)
            cv2.rectangle(eye_img[y:y+h, x:x+w], (ex, ey), (ex+ew, ey+eh), (255, 0, 0), 2)

            cv2.putText(roi_color, label_text, (ex, ey - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 0), 1)

            print(f"[Haar Eye {i+1}] {label_text}")
            print_probs(prediction, class_labels)

        if len(predictions) == 2:
            # After Haar (inside if len(predictions) == 2:)
            left_eye_prediction = predictions[0]
            right_eye_prediction = predictions[1]

            if predictions[0][1] > predictions[1][1]:
                synchronized_label = predictions[0][0]
            else:
                synchronized_label = predictions[1][0]

            



eye_final_label = None

if left_eye_prediction and right_eye_prediction:
    left_label = left_eye_prediction[0]
    right_label = right_eye_prediction[0]

    if left_label == right_label:
        eye_final_label = left_label
    else:
        # You can decide which one is more confident
        if left_eye_prediction[1] > right_eye_prediction[1]:
            eye_final_label = left_label
        else:
            eye_final_label = right_label

# === Final unified logic ===
final_direction = predicted_face_dir

if left_eye_prediction and right_eye_prediction:
    # Get the prediction vectors for both eyes
    left_vector = left_eye_prediction[2]
    right_vector = right_eye_prediction[2]

    # Define individual thresholds
    thresholds = {
        "TopCenter": 0.70,
        "BottomCenter": 0.98  # Less influence
    }

    for label, threshold in thresholds.items():
        idx = eye_labels.index(label)
        if left_vector[idx] > threshold or right_vector[idx] > threshold:
            final_direction = "front"
            break



if predicted_face_dir == "right":
    if left_eye_prediction[0] == "BottomCenter":
        prob_diff = left_eye_prediction[1] - right_eye_prediction[1]
        if prob_diff > 0:
            final_direction = "front"

    elif right_eye_prediction[0] == "BottomCenter":
        prob_diff = right_eye_prediction[1] - left_eye_prediction[1]
        if prob_diff > 0:
            final_direction = "front"

        



if left_eye_prediction[1] > right_eye_prediction[1]:
    synchronized_label = left_pred[0]
else:
    synchronized_label = right_pred[0]

# cv2.putText(img, f"Synchronized: {synchronized_label}", (20, 30),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
#                         print(f"=> Final Syn chronized Label: {synchronized_label}\n")

# === Display results ===
cv2.putText(img, f"Final Direction: {final_direction.upper()}", (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

cv2.imshow("Unified Gaze Output", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# === Console logs ===
print("\n=== Face Direction Model Prediction Scores ===")
for i, label in enumerate(face_labels):
    print(f"{label}: {face_prediction[i]:.4f}")

print(f"\n→ Final Direction: {final_direction.upper()}")

if eye_final_label:
    print("\n=== Eye Model Decision ===")
    print(f"Left Eye: {left_eye_prediction[0]} ({left_eye_prediction[1]:.4f})")
    print(f"Right Eye: {right_eye_prediction[0]} ({right_eye_prediction[1]:.4f})")
    print(f"→ Synchronized Eye Label: {eye_final_label}")
# Out:
# [Left Eye] Left: BottomCenter (0.32)
# Probabilities:
#   BottomCenter: 0.3165
#   BottomLeft: 0.2133
#   BottomRight: 0.2345
#   MiddleLeft: 0.0846
#   MiddleRight: 0.0952
#   TopCenter: 0.0233
#   TopLeft: 0.0249
#   TopRight: 0.0076
# [Right Eye] Right: TopLeft (0.69)
# Probabilities:
#   BottomCenter: 0.0008
#   BottomLeft: 0.0009
#   BottomRight: 0.0014
#   MiddleLeft: 0.0775
#   MiddleRight: 0.0706
#   TopCenter: 0.0295
#   TopLeft: 0.6907
#   TopRight: 0.1286
#
# === Face Direction Model Prediction Scores ===
# left: 0.2695
# right: 0.3532
# front: 0.3773
#
# → Final Direction: RIGHT
#
# === Eye Model Decision ===
# Left Eye: BottomCenter (0.3165)
# Right Eye: TopLeft (0.6907)
# → Synchronized Eye Label: TopLeft

# %%
import cv2
import numpy as np
import mediapipe as mp

# === Load models and labels ===
# Make sure these are defined and loaded properly
# face_model = ...
# eye_model = ...
# face_labels = [...]
# eye_labels = [...]

face_img_size = (128, 128)
eye_img_size = (64, 64)

# === Helper functions ===
def preprocess_eye(eye_roi):
    eye_gray = cv2.cvtColor(eye_roi, cv2.COLOR_BGR2GRAY)
    eye_resized = cv2.resize(eye_gray, eye_img_size)
    eye_array = eye_resized.astype("float32") / 255.0
    eye_array = np.expand_dims(eye_array, axis=[0, -1])
    return eye_array

def predict_eye(eye_array):
    prediction = eye_model.predict(eye_array, verbose=0)[0]
    predicted_idx = np.argmax(prediction)
    return eye_labels[predicted_idx], prediction[predicted_idx], prediction

def print_probs(prediction, class_labels):
    for label, prob in zip(class_labels, prediction):
        print(f"  {label}: {prob:.4f}")

# === Initialize resources ===
cap = cv2.VideoCapture(0)
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    eye_img = frame.copy()
    rgb_img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    h, w = frame.shape[:2]
    
    # === Face direction prediction ===
    face_img_resized = cv2.resize(frame, face_img_size)
    face_img_resized = face_img_resized.astype('float32') / 255.0
    face_img_array = np.expand_dims(face_img_resized, axis=0)
    face_prediction = face_model.predict(face_img_array, verbose=0)[0]
    left, right, front = face_prediction

    diff_front_right = front - right
    if (
        (front >= 0.25 and 0.01 <= diff_front_right <= 0.2) or
        (right > 0.5 and left < 0.25) or
        (right > 2 * left)
    ):
        predicted_face_dir = "right"
    elif (left > right) or (left > 0.2 and right < 0.5):
        predicted_face_dir = "left"
    else:
        predicted_face_dir = face_labels[np.argmax(face_prediction)]

    # === Eye Detection ===
    results = face_mesh.process(rgb_img)
    eye_detected = False
    left_pred = right_pred = None

    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            left_eye_indices = [33, 133]
            right_eye_indices = [362, 263]

            def extract_eye_region(indices):
                x_coords = [int(face_landmarks.landmark[i].x * w) for i in indices]
                y_coords = [int(face_landmarks.landmark[i].y * h) for i in indices]
                x_min, x_max = min(x_coords), max(x_coords)
                y_min, y_max = min(y_coords), max(y_coords)
                margin_x = int((x_max - x_min) * 0.4)
                margin_y = int((y_max - y_min) * 1.2)
                x1 = max(x_min - margin_x, 0)
                y1 = max(y_min - margin_y, 0)
                x2 = min(x_max + margin_x, w)
                y2 = min(y_max + margin_y, h)
                return x1, y1, x2, y2

            for eye_label, indices in zip(["Left", "Right"], [left_eye_indices, right_eye_indices]):
                x1, y1, x2, y2 = extract_eye_region(indices)
                eye_roi = frame[y1:y2, x1:x2]
                if eye_roi.size == 0:
                    continue
                eye_array = preprocess_eye(eye_roi)
                predicted_label, predicted_prob, prediction = predict_eye(eye_array)

                if eye_label == "Left":
                    left_pred = (predicted_label, predicted_prob, prediction)
                else:
                    right_pred = (predicted_label, predicted_prob, prediction)

                label_text = f"{eye_label}: {predicted_label} ({predicted_prob:.2f})"
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, label_text, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

                print(f"[{eye_label} Eye] {label_text}")
                print_probs(prediction, eye_labels)
                eye_detected = True

    if not eye_detected:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x, y, w1, h1) in faces:
            roi_color = frame[y:y+h1, x:x+w1]
            eyes = eye_cascade.detectMultiScale(cv2.cvtColor(roi_color, cv2.COLOR_BGR2GRAY))
            for i, (ex, ey, ew, eh) in enumerate(eyes[:2]):
                eye_roi = roi_color[ey:ey+eh, ex:ex+ew]
                if eye_roi.size == 0:
                    continue
                eye_array = preprocess_eye(eye_roi)
                predicted_label, predicted_prob, prediction = predict_eye(eye_array)

                if i == 0:
                    left_pred = (predicted_label, predicted_prob, prediction)
                else:
                    right_pred = (predicted_label, predicted_prob, prediction)

                label_text = f"Eye{i+1}: {predicted_label} ({predicted_prob:.2f})"
                cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (255, 0, 0), 2)
                cv2.putText(roi_color, label_text, (ex, ey - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 0), 1)

    # === Final Decision Logic ===
    final_direction = predicted_face_dir
    if left_pred and right_pred:
        left_vector = left_pred[2]
        right_vector = right_pred[2]
        thresholds = {
            "TopCenter": 0.70,
            "BottomCenter": 0.98
        }
        for label, threshold in thresholds.items():
            idx = eye_labels.index(label)
            if left_vector[idx] > threshold or right_vector[idx] > threshold:
                final_direction = "front"
                break

        if predicted_face_dir == "right" and (
            (left_pred[0] == "BottomCenter" and left_pred[1] > right_pred[1]) or
            (right_pred[0] == "BottomCenter" and right_pred[1] > left_pred[1])
        ):
            final_direction = "front"

    # === Display Results ===
    cv2.putText(frame, f"Final Direction: {final_direction}", (20, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2)

    cv2.imshow("Webcam Gaze Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0651
#   BottomLeft: 0.1450
#   BottomRight: 0.1762
#   MiddleLeft: 0.1876
#   MiddleRight: 0.1740
#   TopCenter: 0.0416
#   TopLeft: 0.1182
#   TopRight: 0.0924
# [Right Eye] Right: TopCenter (0.50)
#   BottomCenter: 0.2441
#   BottomLeft: 0.0251
#   BottomRight: 0.0905
#   MiddleLeft: 0.0205
#   MiddleRight: 0.0455
#   TopCenter: 0.4977
#   TopLeft: 0.0539
#   TopRight: 0.0227
# [Left Eye] Left: BottomRight (0.41)
#   BottomCenter: 0.0635
#   BottomLeft: 0.2219
#   BottomRight: 0.4119
#   MiddleLeft: 0.1047
#   MiddleRight: 0.1222
#   TopCenter: 0.0102
#   TopLeft: 0.0359
#   TopRight: 0.0298
# [Right Eye] Right: BottomCenter (0.33)
#   BottomCenter: 0.3261
#   BottomLeft: 0.1105
#   BottomRight: 0.3058
#   MiddleLeft: 0.0541
#   MiddleRight: 0.0999
#   TopCenter: 0.0669
#   TopLeft: 0.0262
#   TopRight: 0.0104
# [Left Eye] Left: MiddleRight (0.25)
#   BottomCenter: 0.0296
#   BottomLeft: 0.0669
#   BottomRight: 0.2196
#   MiddleLeft: 0.1414
#   MiddleRight: 0.2513
#   TopCenter: 0.0408
#   TopLeft: 0.0944
#   TopRight: 0.1560
# [Right Eye] Right: MiddleLeft (0.33)
#   BottomCenter: 0.0020
#   BottomLeft: 0.2514
#   BottomRight: 0.1941
#   MiddleLeft: 0.3284
#   MiddleRight: 0.1907
#   TopCenter: 0.0001
#   TopLeft: 0.0212
#   TopRight: 0.0121
# [Left Eye] Left: BottomRight (0.32)
#   BottomCenter: 0.1181
#   BottomLeft: 0.1274
#   BottomRight: 0.3244
#   MiddleLeft: 0.0947
#   MiddleRight: 0.1628
#   TopCenter: 0.0413
#   TopLeft: 0.0678
#   TopRight: 0.0634
# [Right Eye] Right: MiddleLeft (0.29)
#   BottomCenter: 0.0295
#   BottomLeft: 0.2138
#   BottomRight: 0.1691
#   MiddleLeft: 0.2950
#   MiddleRight: 0.1303
#   TopCenter: 0.0122
#   TopLeft: 0.1277
#   TopRight: 0.0224
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0541
#   BottomLeft: 0.1320
#   BottomRight: 0.1629
#   MiddleLeft: 0.1925
#   MiddleRight: 0.1702
#   TopCenter: 0.0437
#   TopLeft: 0.1341
#   TopRight: 0.1106
# [Right Eye] Right: MiddleRight (0.51)
#   BottomCenter: 0.0051
#   BottomLeft: 0.0357
#   BottomRight: 0.2200
#   MiddleLeft: 0.1280
#   MiddleRight: 0.5074
#   TopCenter: 0.0028
#   TopLeft: 0.0319
#   TopRight: 0.0691
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0536
#   BottomLeft: 0.1394
#   BottomRight: 0.1708
#   MiddleLeft: 0.1857
#   MiddleRight: 0.1574
#   TopCenter: 0.0446
#   TopLeft: 0.1370
#   TopRight: 0.1115
# [Right Eye] Right: BottomLeft (0.36)
#   BottomCenter: 0.0124
#   BottomLeft: 0.3646
#   BottomRight: 0.2837
#   MiddleLeft: 0.2090
#   MiddleRight: 0.1201
#   TopCenter: 0.0002
#   TopLeft: 0.0078
#   TopRight: 0.0022
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0341
#   BottomLeft: 0.1233
#   BottomRight: 0.1588
#   MiddleLeft: 0.2045
#   MiddleRight: 0.1822
#   TopCenter: 0.0293
#   TopLeft: 0.1418
#   TopRight: 0.1262
# [Right Eye] Right: MiddleLeft (0.33)
#   BottomCenter: 0.0135
#   BottomLeft: 0.1972
#   BottomRight: 0.1772
#   MiddleLeft: 0.3308
#   MiddleRight: 0.2113
#   TopCenter: 0.0032
#   TopLeft: 0.0521
#   TopRight: 0.0147
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0369
#   BottomLeft: 0.1278
#   BottomRight: 0.1520
#   MiddleLeft: 0.2033
#   MiddleRight: 0.1758
#   TopCenter: 0.0325
#   TopLeft: 0.1401
#   TopRight: 0.1316
# [Right Eye] Right: BottomRight (0.31)
#   BottomCenter: 0.1361
#   BottomLeft: 0.0941
#   BottomRight: 0.3107
#   MiddleLeft: 0.0921
#   MiddleRight: 0.2105
#   TopCenter: 0.0499
#   TopLeft: 0.0568
#   TopRight: 0.0498
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0506
#   BottomLeft: 0.1548
#   BottomRight: 0.1836
#   MiddleLeft: 0.1920
#   MiddleRight: 0.1688
#   TopCenter: 0.0309
#   TopLeft: 0.1174
#   TopRight: 0.1017
# [Right Eye] Right: MiddleLeft (0.35)
#   BottomCenter: 0.0007
#   BottomLeft: 0.0187
#   BottomRight: 0.0373
#   MiddleLeft: 0.3524
#   MiddleRight: 0.2731
#   TopCenter: 0.0052
#   TopLeft: 0.1432
#   TopRight: 0.1692
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0254
#   BottomLeft: 0.0971
#   BottomRight: 0.1274
#   MiddleLeft: 0.2073
#   MiddleRight: 0.1740
#   TopCenter: 0.0336
#   TopLeft: 0.1694
#   TopRight: 0.1658
# [Right Eye] Right: MiddleRight (0.31)
#   BottomCenter: 0.0044
#   BottomLeft: 0.0171
#   BottomRight: 0.0345
#   MiddleLeft: 0.2568
#   MiddleRight: 0.3113
#   TopCenter: 0.0160
#   TopLeft: 0.2261
#   TopRight: 0.1337
# [Left Eye] Left: MiddleLeft (0.22)
#   BottomCenter: 0.0242
#   BottomLeft: 0.1099
#   BottomRight: 0.1152
#   MiddleLeft: 0.2178
#   MiddleRight: 0.1562
#   TopCenter: 0.0359
#   TopLeft: 0.1857
#   TopRight: 0.1551
# [Right Eye] Right: MiddleRight (0.58)
#   BottomCenter: 0.0273
#   BottomLeft: 0.0020
#   BottomRight: 0.3647
#   MiddleLeft: 0.0050
#   MiddleRight: 0.5789
#   TopCenter: 0.0023
#   TopLeft: 0.0008
#   TopRight: 0.0191
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0371
#   BottomLeft: 0.1384
#   BottomRight: 0.1583
#   MiddleLeft: 0.2266
#   MiddleRight: 0.1658
#   TopCenter: 0.0298
#   TopLeft: 0.1437
#   TopRight: 0.1004
# [Right Eye] Right: BottomRight (0.27)
#   BottomCenter: 0.0024
#   BottomLeft: 0.2349
#   BottomRight: 0.2661
#   MiddleLeft: 0.2408
#   MiddleRight: 0.2544
#   TopCenter: 0.0000
#   TopLeft: 0.0011
#   TopRight: 0.0004
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0517
#   BottomLeft: 0.1417
#   BottomRight: 0.1771
#   MiddleLeft: 0.1969
#   MiddleRight: 0.1533
#   TopCenter: 0.0399
#   TopLeft: 0.1369
#   TopRight: 0.1024
# [Right Eye] Right: BottomRight (0.67)
#   BottomCenter: 0.0071
#   BottomLeft: 0.3036
#   BottomRight: 0.6745
#   MiddleLeft: 0.0053
#   MiddleRight: 0.0095
#   TopCenter: 0.0000
#   TopLeft: 0.0000
#   TopRight: 0.0000
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0394
#   BottomLeft: 0.1376
#   BottomRight: 0.1577
#   MiddleLeft: 0.2097
#   MiddleRight: 0.1595
#   TopCenter: 0.0316
#   TopLeft: 0.1459
#   TopRight: 0.1186
# [Right Eye] Right: MiddleLeft (0.61)
#   BottomCenter: 0.0036
#   BottomLeft: 0.0571
#   BottomRight: 0.0575
#   MiddleLeft: 0.6125
#   MiddleRight: 0.2144
#   TopCenter: 0.0003
#   TopLeft: 0.0508
#   TopRight: 0.0037
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0380
#   BottomLeft: 0.1231
#   BottomRight: 0.1427
#   MiddleLeft: 0.2052
#   MiddleRight: 0.1539
#   TopCenter: 0.0418
#   TopLeft: 0.1703
#   TopRight: 0.1250
# [Right Eye] Right: MiddleLeft (0.30)
#   BottomCenter: 0.0440
#   BottomLeft: 0.1075
#   BottomRight: 0.1922
#   MiddleLeft: 0.3032
#   MiddleRight: 0.2190
#   TopCenter: 0.0071
#   TopLeft: 0.1167
#   TopRight: 0.0103
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0293
#   BottomLeft: 0.1173
#   BottomRight: 0.1372
#   MiddleLeft: 0.2131
#   MiddleRight: 0.1659
#   TopCenter: 0.0330
#   TopLeft: 0.1649
#   TopRight: 0.1393
# [Right Eye] Right: BottomRight (0.62)
#   BottomCenter: 0.1382
#   BottomLeft: 0.1574
#   BottomRight: 0.6217
#   MiddleLeft: 0.0309
#   MiddleRight: 0.0494
#   TopCenter: 0.0004
#   TopLeft: 0.0017
#   TopRight: 0.0004
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0478
#   BottomLeft: 0.1085
#   BottomRight: 0.1481
#   MiddleLeft: 0.1938
#   MiddleRight: 0.1798
#   TopCenter: 0.0453
#   TopLeft: 0.1479
#   TopRight: 0.1287
# [Right Eye] Right: MiddleRight (0.45)
#   BottomCenter: 0.0170
#   BottomLeft: 0.0198
#   BottomRight: 0.1379
#   MiddleLeft: 0.1229
#   MiddleRight: 0.4548
#   TopCenter: 0.0284
#   TopLeft: 0.0820
#   TopRight: 0.1373
# [Left Eye] Left: MiddleLeft (0.22)
#   BottomCenter: 0.0356
#   BottomLeft: 0.1277
#   BottomRight: 0.1436
#   MiddleLeft: 0.2158
#   MiddleRight: 0.1655
#   TopCenter: 0.0331
#   TopLeft: 0.1522
#   TopRight: 0.1266
# [Right Eye] Right: BottomRight (0.56)
#   BottomCenter: 0.0152
#   BottomLeft: 0.1563
#   BottomRight: 0.5609
#   MiddleLeft: 0.0586
#   MiddleRight: 0.1949
#   TopCenter: 0.0004
#   TopLeft: 0.0065
#   TopRight: 0.0072
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0403
#   BottomLeft: 0.0873
#   BottomRight: 0.1195
#   MiddleLeft: 0.1930
#   MiddleRight: 0.1596
#   TopCenter: 0.0603
#   TopLeft: 0.1842
#   TopRight: 0.1558
# [Right Eye] Right: MiddleRight (0.28)
#   BottomCenter: 0.0025
#   BottomLeft: 0.0341
#   BottomRight: 0.0803
#   MiddleLeft: 0.2085
#   MiddleRight: 0.2785
#   TopCenter: 0.0129
#   TopLeft: 0.1788
#   TopRight: 0.2043
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0301
#   BottomLeft: 0.0790
#   BottomRight: 0.1184
#   MiddleLeft: 0.1902
#   MiddleRight: 0.1795
#   TopCenter: 0.0480
#   TopLeft: 0.1777
#   TopRight: 0.1771
# [Right Eye] Right: MiddleLeft (0.29)
#   BottomCenter: 0.0223
#   BottomLeft: 0.1273
#   BottomRight: 0.1409
#   MiddleLeft: 0.2926
#   MiddleRight: 0.2138
#   TopCenter: 0.0108
#   TopLeft: 0.1423
#   TopRight: 0.0500
# [Left Eye] Left: MiddleRight (0.19)
#   BottomCenter: 0.0455
#   BottomLeft: 0.1188
#   BottomRight: 0.1818
#   MiddleLeft: 0.1852
#   MiddleRight: 0.1921
#   TopCenter: 0.0333
#   TopLeft: 0.1183
#   TopRight: 0.1250
# [Right Eye] Right: BottomLeft (0.63)
#   BottomCenter: 0.0372
#   BottomLeft: 0.6328
#   BottomRight: 0.2795
#   MiddleLeft: 0.0330
#   MiddleRight: 0.0173
#   TopCenter: 0.0000
#   TopLeft: 0.0003
#   TopRight: 0.0000
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0476
#   BottomLeft: 0.1528
#   BottomRight: 0.1678
#   MiddleLeft: 0.1966
#   MiddleRight: 0.1634
#   TopCenter: 0.0345
#   TopLeft: 0.1280
#   TopRight: 0.1093
# [Right Eye] Right: BottomRight (0.44)
#   BottomCenter: 0.0079
#   BottomLeft: 0.0680
#   BottomRight: 0.4401
#   MiddleLeft: 0.0853
#   MiddleRight: 0.3601
#   TopCenter: 0.0009
#   TopLeft: 0.0148
#   TopRight: 0.0228
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0441
#   BottomLeft: 0.1462
#   BottomRight: 0.1622
#   MiddleLeft: 0.2064
#   MiddleRight: 0.1696
#   TopCenter: 0.0311
#   TopLeft: 0.1317
#   TopRight: 0.1087
# [Right Eye] Right: MiddleRight (0.28)
#   BottomCenter: 0.0101
#   BottomLeft: 0.1435
#   BottomRight: 0.2682
#   MiddleLeft: 0.2570
#   MiddleRight: 0.2786
#   TopCenter: 0.0009
#   TopLeft: 0.0313
#   TopRight: 0.0104
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0610
#   BottomLeft: 0.1472
#   BottomRight: 0.1779
#   MiddleLeft: 0.1854
#   MiddleRight: 0.1655
#   TopCenter: 0.0393
#   TopLeft: 0.1239
#   TopRight: 0.0997
# [Right Eye] Right: MiddleRight (0.29)
#   BottomCenter: 0.1284
#   BottomLeft: 0.0483
#   BottomRight: 0.2593
#   MiddleLeft: 0.0841
#   MiddleRight: 0.2878
#   TopCenter: 0.0620
#   TopLeft: 0.0855
#   TopRight: 0.0446
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0475
#   BottomLeft: 0.1332
#   BottomRight: 0.1544
#   MiddleLeft: 0.1939
#   MiddleRight: 0.1741
#   TopCenter: 0.0387
#   TopLeft: 0.1339
#   TopRight: 0.1242
# [Right Eye] Right: BottomRight (0.60)
#   BottomCenter: 0.1633
#   BottomLeft: 0.0080
#   BottomRight: 0.5987
#   MiddleLeft: 0.0025
#   MiddleRight: 0.1791
#   TopCenter: 0.0207
#   TopLeft: 0.0020
#   TopRight: 0.0255
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0512
#   BottomLeft: 0.1427
#   BottomRight: 0.1500
#   MiddleLeft: 0.1986
#   MiddleRight: 0.1629
#   TopCenter: 0.0426
#   TopLeft: 0.1375
#   TopRight: 0.1145
# [Right Eye] Right: MiddleRight (0.45)
#   BottomCenter: 0.0031
#   BottomLeft: 0.0078
#   BottomRight: 0.1483
#   MiddleLeft: 0.0370
#   MiddleRight: 0.4478
#   TopCenter: 0.0134
#   TopLeft: 0.0260
#   TopRight: 0.3166
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0586
#   BottomLeft: 0.1430
#   BottomRight: 0.1637
#   MiddleLeft: 0.1892
#   MiddleRight: 0.1712
#   TopCenter: 0.0421
#   TopLeft: 0.1244
#   TopRight: 0.1077
# [Right Eye] Right: MiddleRight (0.47)
#   BottomCenter: 0.0005
#   BottomLeft: 0.0090
#   BottomRight: 0.0395
#   MiddleLeft: 0.2082
#   MiddleRight: 0.4745
#   TopCenter: 0.0024
#   TopLeft: 0.0618
#   TopRight: 0.2041
# [Left Eye] Left: MiddleRight (0.19)
#   BottomCenter: 0.0561
#   BottomLeft: 0.1163
#   BottomRight: 0.1601
#   MiddleLeft: 0.1748
#   MiddleRight: 0.1888
#   TopCenter: 0.0481
#   TopLeft: 0.1247
#   TopRight: 0.1311
# [Right Eye] Right: TopRight (0.46)
#   BottomCenter: 0.0085
#   BottomLeft: 0.0001
#   BottomRight: 0.0671
#   MiddleLeft: 0.0005
#   MiddleRight: 0.3227
#   TopCenter: 0.1344
#   TopLeft: 0.0020
#   TopRight: 0.4648
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0688
#   BottomLeft: 0.1445
#   BottomRight: 0.2084
#   MiddleLeft: 0.1676
#   MiddleRight: 0.1924
#   TopCenter: 0.0322
#   TopLeft: 0.0891
#   TopRight: 0.0968
# [Right Eye] Right: MiddleLeft (0.22)
#   BottomCenter: 0.0390
#   BottomLeft: 0.1072
#   BottomRight: 0.1784
#   MiddleLeft: 0.2156
#   MiddleRight: 0.1896
#   TopCenter: 0.0340
#   TopLeft: 0.1162
#   TopRight: 0.1200
# [Left Eye] Left: BottomRight (0.18)
#   BottomCenter: 0.0613
#   BottomLeft: 0.1572
#   BottomRight: 0.1829
#   MiddleLeft: 0.1824
#   MiddleRight: 0.1715
#   TopCenter: 0.0359
#   TopLeft: 0.1061
#   TopRight: 0.1026
# [Right Eye] Right: BottomRight (0.47)
#   BottomCenter: 0.1754
#   BottomLeft: 0.2183
#   BottomRight: 0.4666
#   MiddleLeft: 0.0261
#   MiddleRight: 0.0872
#   TopCenter: 0.0055
#   TopLeft: 0.0172
#   TopRight: 0.0038
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0501
#   BottomLeft: 0.1424
#   BottomRight: 0.1683
#   MiddleLeft: 0.1889
#   MiddleRight: 0.1789
#   TopCenter: 0.0355
#   TopLeft: 0.1163
#   TopRight: 0.1196
# [Right Eye] Right: MiddleLeft (0.19)
#   BottomCenter: 0.0587
#   BottomLeft: 0.1281
#   BottomRight: 0.1566
#   MiddleLeft: 0.1853
#   MiddleRight: 0.1642
#   TopCenter: 0.0518
#   TopLeft: 0.1379
#   TopRight: 0.1175
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0604
#   BottomLeft: 0.1558
#   BottomRight: 0.1929
#   MiddleLeft: 0.1766
#   MiddleRight: 0.1816
#   TopCenter: 0.0312
#   TopLeft: 0.0971
#   TopRight: 0.1044
# [Right Eye] Right: BottomCenter (0.25)
#   BottomCenter: 0.2511
#   BottomLeft: 0.1592
#   BottomRight: 0.0765
#   MiddleLeft: 0.1547
#   MiddleRight: 0.0702
#   TopCenter: 0.1299
#   TopLeft: 0.1200
#   TopRight: 0.0384
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0552
#   BottomLeft: 0.1740
#   BottomRight: 0.1805
#   MiddleLeft: 0.1935
#   MiddleRight: 0.1622
#   TopCenter: 0.0299
#   TopLeft: 0.1090
#   TopRight: 0.0958
# [Right Eye] Right: MiddleLeft (0.21)
#   BottomCenter: 0.0436
#   BottomLeft: 0.1308
#   BottomRight: 0.1421
#   MiddleLeft: 0.2095
#   MiddleRight: 0.1673
#   TopCenter: 0.0393
#   TopLeft: 0.1460
#   TopRight: 0.1214
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0670
#   BottomLeft: 0.1780
#   BottomRight: 0.2126
#   MiddleLeft: 0.1757
#   MiddleRight: 0.1738
#   TopCenter: 0.0276
#   TopLeft: 0.0869
#   TopRight: 0.0783
# [Right Eye] Right: MiddleLeft (0.21)
#   BottomCenter: 0.0212
#   BottomLeft: 0.1191
#   BottomRight: 0.1419
#   MiddleLeft: 0.2070
#   MiddleRight: 0.1975
#   TopCenter: 0.0605
#   TopLeft: 0.1498
#   TopRight: 0.1029
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0568
#   BottomLeft: 0.1651
#   BottomRight: 0.1922
#   MiddleLeft: 0.1870
#   MiddleRight: 0.1817
#   TopCenter: 0.0276
#   TopLeft: 0.0949
#   TopRight: 0.0947
# [Right Eye] Right: TopLeft (0.34)
#   BottomCenter: 0.0039
#   BottomLeft: 0.0465
#   BottomRight: 0.0220
#   MiddleLeft: 0.2743
#   MiddleRight: 0.0968
#   TopCenter: 0.0323
#   TopLeft: 0.3397
#   TopRight: 0.1845
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0622
#   BottomLeft: 0.1688
#   BottomRight: 0.1737
#   MiddleLeft: 0.1896
#   MiddleRight: 0.1634
#   TopCenter: 0.0355
#   TopLeft: 0.1092
#   TopRight: 0.0976
# [Right Eye] Right: MiddleRight (0.36)
#   BottomCenter: 0.0045
#   BottomLeft: 0.0201
#   BottomRight: 0.0803
#   MiddleLeft: 0.1716
#   MiddleRight: 0.3598
#   TopCenter: 0.0141
#   TopLeft: 0.0946
#   TopRight: 0.2550
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0690
#   BottomLeft: 0.1903
#   BottomRight: 0.1910
#   MiddleLeft: 0.1838
#   MiddleRight: 0.1542
#   TopCenter: 0.0326
#   TopLeft: 0.0985
#   TopRight: 0.0806
# [Right Eye] Right: TopRight (0.34)
#   BottomCenter: 0.0034
#   BottomLeft: 0.0257
#   BottomRight: 0.0327
#   MiddleLeft: 0.1654
#   MiddleRight: 0.1629
#   TopCenter: 0.0349
#   TopLeft: 0.2302
#   TopRight: 0.3448
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0547
#   BottomLeft: 0.1600
#   BottomRight: 0.1790
#   MiddleLeft: 0.1951
#   MiddleRight: 0.1768
#   TopCenter: 0.0314
#   TopLeft: 0.1072
#   TopRight: 0.0958
# [Right Eye] Right: MiddleLeft (0.20)
#   BottomCenter: 0.0491
#   BottomLeft: 0.1418
#   BottomRight: 0.1477
#   MiddleLeft: 0.1981
#   MiddleRight: 0.1505
#   TopCenter: 0.0485
#   TopLeft: 0.1465
#   TopRight: 0.1178
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0577
#   BottomLeft: 0.1300
#   BottomRight: 0.1553
#   MiddleLeft: 0.1888
#   MiddleRight: 0.1797
#   TopCenter: 0.0438
#   TopLeft: 0.1282
#   TopRight: 0.1165
# [Left Eye] Left: MiddleRight (0.26)
#   BottomCenter: 0.0909
#   BottomLeft: 0.0046
#   BottomRight: 0.2122
#   MiddleLeft: 0.0078
#   MiddleRight: 0.2609
#   TopCenter: 0.2287
#   TopLeft: 0.0127
#   TopRight: 0.1821
# [Right Eye] Right: MiddleRight (0.19)
#   BottomCenter: 0.0419
#   BottomLeft: 0.0750
#   BottomRight: 0.1588
#   MiddleLeft: 0.1459
#   MiddleRight: 0.1949
#   TopCenter: 0.0640
#   TopLeft: 0.1560
#   TopRight: 0.1634
# [Left Eye] Left: MiddleRight (0.18)
#   BottomCenter: 0.0444
#   BottomLeft: 0.1139
#   BottomRight: 0.1627
#   MiddleLeft: 0.1735
#   MiddleRight: 0.1821
#   TopCenter: 0.0508
#   TopLeft: 0.1407
#   TopRight: 0.1319
# [Right Eye] Right: TopCenter (0.47)
#   BottomCenter: 0.0814
#   BottomLeft: 0.0136
#   BottomRight: 0.1038
#   MiddleLeft: 0.0232
#   MiddleRight: 0.1122
#   TopCenter: 0.4662
#   TopLeft: 0.0673
#   TopRight: 0.1323
# [Left Eye] Left: TopRight (0.20)
#   BottomCenter: 0.0258
#   BottomLeft: 0.0712
#   BottomRight: 0.1084
#   MiddleLeft: 0.1738
#   MiddleRight: 0.1878
#   TopCenter: 0.0570
#   TopLeft: 0.1725
#   TopRight: 0.2034
# [Right Eye] Right: BottomRight (0.37)
#   BottomCenter: 0.1478
#   BottomLeft: 0.0644
#   BottomRight: 0.3681
#   MiddleLeft: 0.0396
#   MiddleRight: 0.1568
#   TopCenter: 0.1137
#   TopLeft: 0.0470
#   TopRight: 0.0625
# [Left Eye] Left: MiddleRight (0.21)
#   BottomCenter: 0.0513
#   BottomLeft: 0.0407
#   BottomRight: 0.1408
#   MiddleLeft: 0.0975
#   MiddleRight: 0.2128
#   TopCenter: 0.1372
#   TopLeft: 0.1222
#   TopRight: 0.1975
# [Right Eye] Right: BottomRight (0.32)
#   BottomCenter: 0.0298
#   BottomLeft: 0.1562
#   BottomRight: 0.3171
#   MiddleLeft: 0.1219
#   MiddleRight: 0.1575
#   TopCenter: 0.0269
#   TopLeft: 0.1033
#   TopRight: 0.0872
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0509
#   BottomLeft: 0.1179
#   BottomRight: 0.1415
#   MiddleLeft: 0.1894
#   MiddleRight: 0.1670
#   TopCenter: 0.0522
#   TopLeft: 0.1550
#   TopRight: 0.1261
# [Right Eye] Right: MiddleLeft (0.19)
#   BottomCenter: 0.0483
#   BottomLeft: 0.1322
#   BottomRight: 0.1698
#   MiddleLeft: 0.1869
#   MiddleRight: 0.1746
#   TopCenter: 0.0391
#   TopLeft: 0.1305
#   TopRight: 0.1187
# [Left Eye] Left: BottomRight (0.22)
#   BottomCenter: 0.0746
#   BottomLeft: 0.1501
#   BottomRight: 0.2222
#   MiddleLeft: 0.1542
#   MiddleRight: 0.1889
#   TopCenter: 0.0362
#   TopLeft: 0.0845
#   TopRight: 0.0895
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0618
#   BottomLeft: 0.1576
#   BottomRight: 0.2067
#   MiddleLeft: 0.1693
#   MiddleRight: 0.1808
#   TopCenter: 0.0314
#   TopLeft: 0.0948
#   TopRight: 0.0975
# [Right Eye] Right: TopLeft (0.27)
#   BottomCenter: 0.0556
#   BottomLeft: 0.0756
#   BottomRight: 0.0603
#   MiddleLeft: 0.2055
#   MiddleRight: 0.1227
#   TopCenter: 0.0953
#   TopLeft: 0.2654
#   TopRight: 0.1196
# [Left Eye] Left: BottomRight (0.20)
#   BottomCenter: 0.0732
#   BottomLeft: 0.1827
#   BottomRight: 0.2046
#   MiddleLeft: 0.1834
#   MiddleRight: 0.1637
#   TopCenter: 0.0304
#   TopLeft: 0.0917
#   TopRight: 0.0702
# [Right Eye] Right: BottomRight (0.49)
#   BottomCenter: 0.2187
#   BottomLeft: 0.1539
#   BottomRight: 0.4921
#   MiddleLeft: 0.0183
#   MiddleRight: 0.0774
#   TopCenter: 0.0194
#   TopLeft: 0.0102
#   TopRight: 0.0102
# [Left Eye] Left: BottomRight (0.20)
#   BottomCenter: 0.0825
#   BottomLeft: 0.1359
#   BottomRight: 0.2047
#   MiddleLeft: 0.1608
#   MiddleRight: 0.1715
#   TopCenter: 0.0474
#   TopLeft: 0.1061
#   TopRight: 0.0911
# [Right Eye] Right: TopCenter (0.37)
#   BottomCenter: 0.0722
#   BottomLeft: 0.0270
#   BottomRight: 0.0227
#   MiddleLeft: 0.1192
#   MiddleRight: 0.0541
#   TopCenter: 0.3680
#   TopLeft: 0.2977
#   TopRight: 0.0392
# [Left Eye] Left: MiddleRight (0.26)
#   BottomCenter: 0.0482
#   BottomLeft: 0.0544
#   BottomRight: 0.1954
#   MiddleLeft: 0.1174
#   MiddleRight: 0.2597
#   TopCenter: 0.0666
#   TopLeft: 0.1114
#   TopRight: 0.1469
# [Right Eye] Right: BottomRight (0.27)
#   BottomCenter: 0.0282
#   BottomLeft: 0.2485
#   BottomRight: 0.2692
#   MiddleLeft: 0.2175
#   MiddleRight: 0.1841
#   TopCenter: 0.0021
#   TopLeft: 0.0358
#   TopRight: 0.0147
# [Left Eye] Left: TopCenter (0.61)
#   BottomCenter: 0.0730
#   BottomLeft: 0.0010
#   BottomRight: 0.0585
#   MiddleLeft: 0.0035
#   MiddleRight: 0.1278
#   TopCenter: 0.6118
#   TopLeft: 0.0078
#   TopRight: 0.1166
# [Right Eye] Right: TopRight (0.40)
#   BottomCenter: 0.0001
#   BottomLeft: 0.0019
#   BottomRight: 0.0033
#   MiddleLeft: 0.0942
#   MiddleRight: 0.0633
#   TopCenter: 0.0459
#   TopLeft: 0.3930
#   TopRight: 0.3983
# [Left Eye] Left: TopCenter (0.38)
#   BottomCenter: 0.0384
#   BottomLeft: 0.0059
#   BottomRight: 0.0896
#   MiddleLeft: 0.0219
#   MiddleRight: 0.1848
#   TopCenter: 0.3785
#   TopLeft: 0.0542
#   TopRight: 0.2268
# [Right Eye] Right: TopLeft (0.58)
#   BottomCenter: 0.0000
#   BottomLeft: 0.0001
#   BottomRight: 0.0002
#   MiddleLeft: 0.0330
#   MiddleRight: 0.0169
#   TopCenter: 0.1101
#   TopLeft: 0.5781
#   TopRight: 0.2616
# [Left Eye] Left: TopCenter (0.76)
#   BottomCenter: 0.0374
#   BottomLeft: 0.0010
#   BottomRight: 0.0244
#   MiddleLeft: 0.0057
#   MiddleRight: 0.0662
#   TopCenter: 0.7585
#   TopLeft: 0.0188
#   TopRight: 0.0880
# [Right Eye] Right: TopLeft (0.62)
#   BottomCenter: 0.0000
#   BottomLeft: 0.0000
#   BottomRight: 0.0000
#   MiddleLeft: 0.0180
#   MiddleRight: 0.0090
#   TopCenter: 0.0896
#   TopLeft: 0.6215
#   TopRight: 0.2618
# [Left Eye] Left: TopCenter (0.40)
#   BottomCenter: 0.0571
#   BottomLeft: 0.0029
#   BottomRight: 0.0901
#   MiddleLeft: 0.0110
#   MiddleRight: 0.2093
#   TopCenter: 0.4029
#   TopLeft: 0.0243
#   TopRight: 0.2025
# [Right Eye] Right: TopLeft (0.47)
#   BottomCenter: 0.0002
#   BottomLeft: 0.0002
#   BottomRight: 0.0005
#   MiddleLeft: 0.0310
#   MiddleRight: 0.0275
#   TopCenter: 0.1420
#   TopLeft: 0.4666
#   TopRight: 0.3321
# [Left Eye] Left: TopCenter (0.49)
#   BottomCenter: 0.0767
#   BottomLeft: 0.0043
#   BottomRight: 0.0837
#   MiddleLeft: 0.0155
#   MiddleRight: 0.1591
#   TopCenter: 0.4945
#   TopLeft: 0.0342
#   TopRight: 0.1320
# [Right Eye] Right: TopLeft (0.61)
#   BottomCenter: 0.0000
#   BottomLeft: 0.0000
#   BottomRight: 0.0001
#   MiddleLeft: 0.0205
#   MiddleRight: 0.0108
#   TopCenter: 0.0652
#   TopLeft: 0.6067
#   TopRight: 0.2968
# [Left Eye] Left: MiddleRight (0.32)
#   BottomCenter: 0.0328
#   BottomLeft: 0.0441
#   BottomRight: 0.2252
#   MiddleLeft: 0.0964
#   MiddleRight: 0.3224
#   TopCenter: 0.0342
#   TopLeft: 0.0780
#   TopRight: 0.1669
# [Right Eye] Right: TopRight (0.55)
#   BottomCenter: 0.0000
#   BottomLeft: 0.0001
#   BottomRight: 0.0004
#   MiddleLeft: 0.0299
#   MiddleRight: 0.0418
#   TopCenter: 0.0234
#   TopLeft: 0.3503
#   TopRight: 0.5541
# [Left Eye] Left: MiddleRight (0.25)
#   BottomCenter: 0.0699
#   BottomLeft: 0.0615
#   BottomRight: 0.2403
#   MiddleLeft: 0.0865
#   MiddleRight: 0.2502
#   TopCenter: 0.0660
#   TopLeft: 0.0770
#   TopRight: 0.1485
# [Right Eye] Right: BottomLeft (0.64)
#   BottomCenter: 0.0654
#   BottomLeft: 0.6396
#   BottomRight: 0.1391
#   MiddleLeft: 0.1293
#   MiddleRight: 0.0194
#   TopCenter: 0.0003
#   TopLeft: 0.0067
#   TopRight: 0.0002
# [Left Eye] Left: MiddleLeft (0.17)
#   BottomCenter: 0.0559
#   BottomLeft: 0.1145
#   BottomRight: 0.1581
#   MiddleLeft: 0.1745
#   MiddleRight: 0.1700
#   TopCenter: 0.0531
#   TopLeft: 0.1423
#   TopRight: 0.1315
# [Right Eye] Right: TopLeft (0.32)
#   BottomCenter: 0.0315
#   BottomLeft: 0.1695
#   BottomRight: 0.0480
#   MiddleLeft: 0.2789
#   MiddleRight: 0.0441
#   TopCenter: 0.0767
#   TopLeft: 0.3224
#   TopRight: 0.0289
# [Left Eye] Left: MiddleRight (0.18)
#   BottomCenter: 0.0481
#   BottomLeft: 0.1061
#   BottomRight: 0.1363
#   MiddleLeft: 0.1806
#   MiddleRight: 0.1820
#   TopCenter: 0.0541
#   TopLeft: 0.1526
#   TopRight: 0.1402
# [Right Eye] Right: MiddleRight (0.46)
#   BottomCenter: 0.0190
#   BottomLeft: 0.0133
#   BottomRight: 0.1009
#   MiddleLeft: 0.0911
#   MiddleRight: 0.4649
#   TopCenter: 0.0723
#   TopLeft: 0.0840
#   TopRight: 0.1545
# [Left Eye] Left: MiddleRight (0.20)
#   BottomCenter: 0.0458
#   BottomLeft: 0.1100
#   BottomRight: 0.1706
#   MiddleLeft: 0.1661
#   MiddleRight: 0.2010
#   TopCenter: 0.0385
#   TopLeft: 0.1199
#   TopRight: 0.1481
# [Right Eye] Right: TopCenter (0.22)
#   BottomCenter: 0.1377
#   BottomLeft: 0.0482
#   BottomRight: 0.1086
#   MiddleLeft: 0.1103
#   MiddleRight: 0.1861
#   TopCenter: 0.2245
#   TopLeft: 0.1270
#   TopRight: 0.0576
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0611
#   BottomLeft: 0.1707
#   BottomRight: 0.1674
#   MiddleLeft: 0.1873
#   MiddleRight: 0.1534
#   TopCenter: 0.0393
#   TopLeft: 0.1218
#   TopRight: 0.0989
# [Right Eye] Right: MiddleRight (0.39)
#   BottomCenter: 0.0260
#   BottomLeft: 0.0048
#   BottomRight: 0.2023
#   MiddleLeft: 0.0122
#   MiddleRight: 0.3877
#   TopCenter: 0.0688
#   TopLeft: 0.0149
#   TopRight: 0.2833
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0478
#   BottomLeft: 0.1499
#   BottomRight: 0.1154
#   MiddleLeft: 0.2261
#   MiddleRight: 0.1450
#   TopCenter: 0.0498
#   TopLeft: 0.1631
#   TopRight: 0.1027
# [Right Eye] Right: MiddleLeft (0.29)
#   BottomCenter: 0.0214
#   BottomLeft: 0.1210
#   BottomRight: 0.2507
#   MiddleLeft: 0.2945
#   MiddleRight: 0.2471
#   TopCenter: 0.0039
#   TopLeft: 0.0467
#   TopRight: 0.0147
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0664
#   BottomLeft: 0.1855
#   BottomRight: 0.1899
#   MiddleLeft: 0.1758
#   MiddleRight: 0.1551
#   TopCenter: 0.0344
#   TopLeft: 0.1032
#   TopRight: 0.0897
# [Right Eye] Right: BottomRight (0.66)
#   BottomCenter: 0.0870
#   BottomLeft: 0.1719
#   BottomRight: 0.6594
#   MiddleLeft: 0.0173
#   MiddleRight: 0.0619
#   TopCenter: 0.0004
#   TopLeft: 0.0011
#   TopRight: 0.0009
# [Left Eye] Left: BottomLeft (0.21)
#   BottomCenter: 0.0809
#   BottomLeft: 0.2051
#   BottomRight: 0.1989
#   MiddleLeft: 0.1690
#   MiddleRight: 0.1448
#   TopCenter: 0.0364
#   TopLeft: 0.0924
#   TopRight: 0.0724
# [Right Eye] Right: MiddleRight (0.22)
#   BottomCenter: 0.0280
#   BottomLeft: 0.0751
#   BottomRight: 0.1098
#   MiddleLeft: 0.2064
#   MiddleRight: 0.2175
#   TopCenter: 0.0358
#   TopLeft: 0.1407
#   TopRight: 0.1866
# [Left Eye] Left: BottomRight (0.20)
#   BottomCenter: 0.0668
#   BottomLeft: 0.1782
#   BottomRight: 0.1991
#   MiddleLeft: 0.1789
#   MiddleRight: 0.1714
#   TopCenter: 0.0300
#   TopLeft: 0.0907
#   TopRight: 0.0849
# [Right Eye] Right: MiddleRight (0.19)
#   BottomCenter: 0.0429
#   BottomLeft: 0.1085
#   BottomRight: 0.1547
#   MiddleLeft: 0.1898
#   MiddleRight: 0.1906
#   TopCenter: 0.0365
#   TopLeft: 0.1366
#   TopRight: 0.1405
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0441
#   BottomLeft: 0.1997
#   BottomRight: 0.1930
#   MiddleLeft: 0.2104
#   MiddleRight: 0.1574
#   TopCenter: 0.0211
#   TopLeft: 0.1018
#   TopRight: 0.0724
# [Right Eye] Right: BottomRight (0.33)
#   BottomCenter: 0.0821
#   BottomLeft: 0.0723
#   BottomRight: 0.3266
#   MiddleLeft: 0.0623
#   MiddleRight: 0.2321
#   TopCenter: 0.0777
#   TopLeft: 0.0542
#   TopRight: 0.0927
# [Left Eye] Left: BottomLeft (0.25)
#   BottomCenter: 0.0686
#   BottomLeft: 0.2522
#   BottomRight: 0.1510
#   MiddleLeft: 0.2131
#   MiddleRight: 0.1145
#   TopCenter: 0.0325
#   TopLeft: 0.1144
#   TopRight: 0.0538
# [Right Eye] Right: MiddleLeft (0.33)
#   BottomCenter: 0.0519
#   BottomLeft: 0.2035
#   BottomRight: 0.1199
#   MiddleLeft: 0.3272
#   MiddleRight: 0.1172
#   TopCenter: 0.0225
#   TopLeft: 0.1292
#   TopRight: 0.0286
# [Left Eye] Left: MiddleRight (0.20)
#   BottomCenter: 0.0583
#   BottomLeft: 0.1079
#   BottomRight: 0.1716
#   MiddleLeft: 0.1706
#   MiddleRight: 0.1963
#   TopCenter: 0.0484
#   TopLeft: 0.1178
#   TopRight: 0.1291
# [Right Eye] Right: TopLeft (0.33)
#   BottomCenter: 0.0140
#   BottomLeft: 0.0991
#   BottomRight: 0.0611
#   MiddleLeft: 0.2243
#   MiddleRight: 0.1128
#   TopCenter: 0.0815
#   TopLeft: 0.3326
#   TopRight: 0.0745
# [Left Eye] Left: MiddleLeft (0.36)
#   BottomCenter: 0.0468
#   BottomLeft: 0.2194
#   BottomRight: 0.0140
#   MiddleLeft: 0.3621
#   MiddleRight: 0.0169
#   TopCenter: 0.0628
#   TopLeft: 0.2641
#   TopRight: 0.0139
# [Right Eye] Right: BottomRight (0.41)
#   BottomCenter: 0.0297
#   BottomLeft: 0.0471
#   BottomRight: 0.4068
#   MiddleLeft: 0.0880
#   MiddleRight: 0.3712
#   TopCenter: 0.0048
#   TopLeft: 0.0175
#   TopRight: 0.0349
# [Right Eye] Right: TopLeft (0.20)
#   BottomCenter: 0.0337
#   BottomLeft: 0.0548
#   BottomRight: 0.0830
#   MiddleLeft: 0.1707
#   MiddleRight: 0.1775
#   TopCenter: 0.0839
#   TopLeft: 0.1985
#   TopRight: 0.1978
# [Left Eye] Left: BottomLeft (0.35)
#   BottomCenter: 0.0703
#   BottomLeft: 0.3509
#   BottomRight: 0.0479
#   MiddleLeft: 0.2838
#   MiddleRight: 0.0292
#   TopCenter: 0.0437
#   TopLeft: 0.1578
#   TopRight: 0.0165
# [Right Eye] Right: MiddleLeft (0.23)
#   BottomCenter: 0.0691
#   BottomLeft: 0.1500
#   BottomRight: 0.1138
#   MiddleLeft: 0.2265
#   MiddleRight: 0.1498
#   TopCenter: 0.0470
#   TopLeft: 0.1731
#   TopRight: 0.0706
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0720
#   BottomLeft: 0.1510
#   BottomRight: 0.1292
#   MiddleLeft: 0.1889
#   MiddleRight: 0.1309
#   TopCenter: 0.0735
#   TopLeft: 0.1564
#   TopRight: 0.0981
# [Right Eye] Right: TopCenter (0.49)
#   BottomCenter: 0.2969
#   BottomLeft: 0.0312
#   BottomRight: 0.0460
#   MiddleLeft: 0.0337
#   MiddleRight: 0.0378
#   TopCenter: 0.4889
#   TopLeft: 0.0507
#   TopRight: 0.0147
# [Left Eye] Left: MiddleRight (0.22)
#   BottomCenter: 0.0393
#   BottomLeft: 0.1362
#   BottomRight: 0.2019
#   MiddleLeft: 0.1660
#   MiddleRight: 0.2226
#   TopCenter: 0.0234
#   TopLeft: 0.0852
#   TopRight: 0.1253
# [Right Eye] Right: MiddleRight (0.33)
#   BottomCenter: 0.0367
#   BottomLeft: 0.0026
#   BottomRight: 0.0611
#   MiddleLeft: 0.0187
#   MiddleRight: 0.3319
#   TopCenter: 0.2742
#   TopLeft: 0.0346
#   TopRight: 0.2402
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0502
#   BottomLeft: 0.1807
#   BottomRight: 0.2063
#   MiddleLeft: 0.1728
#   MiddleRight: 0.1687
#   TopCenter: 0.0266
#   TopLeft: 0.0934
#   TopRight: 0.1013
# [Right Eye] Right: BottomRight (0.24)
#   BottomCenter: 0.0979
#   BottomLeft: 0.0706
#   BottomRight: 0.2419
#   MiddleLeft: 0.0963
#   MiddleRight: 0.2274
#   TopCenter: 0.0662
#   TopLeft: 0.0784
#   TopRight: 0.1213
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0480
#   BottomLeft: 0.1421
#   BottomRight: 0.2136
#   MiddleLeft: 0.1625
#   MiddleRight: 0.2108
#   TopCenter: 0.0261
#   TopLeft: 0.0852
#   TopRight: 0.1117
# [Right Eye] Right: BottomRight (0.42)
#   BottomCenter: 0.0129
#   BottomLeft: 0.0390
#   BottomRight: 0.4187
#   MiddleLeft: 0.0504
#   MiddleRight: 0.2431
#   TopCenter: 0.0265
#   TopLeft: 0.0431
#   TopRight: 0.1662
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.0496
#   BottomLeft: 0.1708
#   BottomRight: 0.2141
#   MiddleLeft: 0.1723
#   MiddleRight: 0.1944
#   TopCenter: 0.0202
#   TopLeft: 0.0824
#   TopRight: 0.0962
# [Right Eye] Right: TopLeft (0.20)
#   BottomCenter: 0.0304
#   BottomLeft: 0.0598
#   BottomRight: 0.0850
#   MiddleLeft: 0.1879
#   MiddleRight: 0.1902
#   TopCenter: 0.0659
#   TopLeft: 0.2021
#   TopRight: 0.1786
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0538
#   BottomLeft: 0.1819
#   BottomRight: 0.1684
#   MiddleLeft: 0.1925
#   MiddleRight: 0.1491
#   TopCenter: 0.0393
#   TopLeft: 0.1235
#   TopRight: 0.0916
# [Right Eye] Right: MiddleLeft (0.18)
#   BottomCenter: 0.0443
#   BottomLeft: 0.1123
#   BottomRight: 0.1130
#   MiddleLeft: 0.1839
#   MiddleRight: 0.1555
#   TopCenter: 0.0557
#   TopLeft: 0.1777
#   TopRight: 0.1577
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0378
#   BottomLeft: 0.1503
#   BottomRight: 0.1344
#   MiddleLeft: 0.2395
#   MiddleRight: 0.1632
#   TopCenter: 0.0295
#   TopLeft: 0.1448
#   TopRight: 0.1005
# [Right Eye] Right: MiddleRight (0.30)
#   BottomCenter: 0.0353
#   BottomLeft: 0.0379
#   BottomRight: 0.2058
#   MiddleLeft: 0.0744
#   MiddleRight: 0.3034
#   TopCenter: 0.0683
#   TopLeft: 0.0711
#   TopRight: 0.2039
# [Left Eye] Left: BottomLeft (0.21)
#   BottomCenter: 0.0435
#   BottomLeft: 0.2085
#   BottomRight: 0.2079
#   MiddleLeft: 0.2059
#   MiddleRight: 0.1517
#   TopCenter: 0.0188
#   TopLeft: 0.0958
#   TopRight: 0.0678
# [Right Eye] Right: BottomRight (0.26)
#   BottomCenter: 0.0589
#   BottomLeft: 0.1750
#   BottomRight: 0.2584
#   MiddleLeft: 0.1684
#   MiddleRight: 0.1718
#   TopCenter: 0.0230
#   TopLeft: 0.0787
#   TopRight: 0.0659
# [Left Eye] Left: BottomRight (0.25)
#   BottomCenter: 0.0154
#   BottomLeft: 0.1758
#   BottomRight: 0.2526
#   MiddleLeft: 0.1804
#   MiddleRight: 0.1694
#   TopCenter: 0.0095
#   TopLeft: 0.0985
#   TopRight: 0.0984
# [Right Eye] Right: TopLeft (0.19)
#   BottomCenter: 0.0410
#   BottomLeft: 0.1027
#   BottomRight: 0.1092
#   MiddleLeft: 0.1913
#   MiddleRight: 0.1624
#   TopCenter: 0.0648
#   TopLeft: 0.1915
#   TopRight: 0.1371
# [Left Eye] Left: MiddleRight (0.23)
#   BottomCenter: 0.0214
#   BottomLeft: 0.0607
#   BottomRight: 0.1488
#   MiddleLeft: 0.1365
#   MiddleRight: 0.2308
#   TopCenter: 0.0427
#   TopLeft: 0.1319
#   TopRight: 0.2272
# [Right Eye] Right: BottomRight (0.37)
#   BottomCenter: 0.0914
#   BottomLeft: 0.0329
#   BottomRight: 0.3679
#   MiddleLeft: 0.0289
#   MiddleRight: 0.2468
#   TopCenter: 0.0918
#   TopLeft: 0.0321
#   TopRight: 0.1082
# [Left Eye] Left: BottomRight (0.25)
#   BottomCenter: 0.0156
#   BottomLeft: 0.1352
#   BottomRight: 0.2463
#   MiddleLeft: 0.1657
#   MiddleRight: 0.2161
#   TopCenter: 0.0140
#   TopLeft: 0.0936
#   TopRight: 0.1135
# [Right Eye] Right: BottomRight (0.47)
#   BottomCenter: 0.1829
#   BottomLeft: 0.1478
#   BottomRight: 0.4718
#   MiddleLeft: 0.0380
#   MiddleRight: 0.0978
#   TopCenter: 0.0204
#   TopLeft: 0.0172
#   TopRight: 0.0242
# [Left Eye] Left: BottomRight (0.21)
#   BottomCenter: 0.1287
#   BottomLeft: 0.1194
#   BottomRight: 0.2127
#   MiddleLeft: 0.1359
#   MiddleRight: 0.1592
#   TopCenter: 0.0772
#   TopLeft: 0.0983
#   TopRight: 0.0686
# [Right Eye] Right: BottomRight (0.33)
#   BottomCenter: 0.0981
#   BottomLeft: 0.0779
#   BottomRight: 0.3346
#   MiddleLeft: 0.0614
#   MiddleRight: 0.1521
#   TopCenter: 0.1047
#   TopLeft: 0.0860
#   TopRight: 0.0852
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0651
#   BottomLeft: 0.1293
#   BottomRight: 0.1531
#   MiddleLeft: 0.1858
#   MiddleRight: 0.1713
#   TopCenter: 0.0520
#   TopLeft: 0.1305
#   TopRight: 0.1130
# [Right Eye] Right: BottomRight (0.17)
#   BottomCenter: 0.1576
#   BottomLeft: 0.0904
#   BottomRight: 0.1667
#   MiddleLeft: 0.0833
#   MiddleRight: 0.1312
#   TopCenter: 0.1386
#   TopLeft: 0.1194
#   TopRight: 0.1128
# [Left Eye] Left: MiddleLeft (0.25)
#   BottomCenter: 0.0401
#   BottomLeft: 0.1310
#   BottomRight: 0.1050
#   MiddleLeft: 0.2451
#   MiddleRight: 0.1423
#   TopCenter: 0.0418
#   TopLeft: 0.1936
#   TopRight: 0.1011
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0530
#   BottomLeft: 0.1519
#   BottomRight: 0.1495
#   MiddleLeft: 0.2112
#   MiddleRight: 0.1641
#   TopCenter: 0.0399
#   TopLeft: 0.1344
#   TopRight: 0.0959
# [Right Eye] Right: MiddleRight (0.18)
#   BottomCenter: 0.0481
#   BottomLeft: 0.1106
#   BottomRight: 0.1489
#   MiddleLeft: 0.1816
#   MiddleRight: 0.1816
#   TopCenter: 0.0493
#   TopLeft: 0.1418
#   TopRight: 0.1381
# [Left Eye] Left: MiddleRight (0.24)
#   BottomCenter: 0.0416
#   BottomLeft: 0.0666
#   BottomRight: 0.1884
#   MiddleLeft: 0.1136
#   MiddleRight: 0.2398
#   TopCenter: 0.0523
#   TopLeft: 0.1015
#   TopRight: 0.1963
# [Right Eye] Right: BottomRight (0.42)
#   BottomCenter: 0.1966
#   BottomLeft: 0.2333
#   BottomRight: 0.4191
#   MiddleLeft: 0.0485
#   MiddleRight: 0.0966
#   TopCenter: 0.0011
#   TopLeft: 0.0034
#   TopRight: 0.0014
# [Left Eye] Left: MiddleRight (0.27)
#   BottomCenter: 0.0554
#   BottomLeft: 0.0089
#   BottomRight: 0.1463
#   MiddleLeft: 0.0231
#   MiddleRight: 0.2690
#   TopCenter: 0.1892
#   TopLeft: 0.0555
#   TopRight: 0.2528
# [Right Eye] Right: BottomLeft (0.66)
#   BottomCenter: 0.0165
#   BottomLeft: 0.6594
#   BottomRight: 0.0770
#   MiddleLeft: 0.2194
#   MiddleRight: 0.0161
#   TopCenter: 0.0001
#   TopLeft: 0.0112
#   TopRight: 0.0003
# [Left Eye] Left: BottomRight (0.27)
#   BottomCenter: 0.1755
#   BottomLeft: 0.0056
#   BottomRight: 0.2710
#   MiddleLeft: 0.0051
#   MiddleRight: 0.1833
#   TopCenter: 0.2594
#   TopLeft: 0.0106
#   TopRight: 0.0895
# [Right Eye] Right: MiddleLeft (0.34)
#   BottomCenter: 0.0032
#   BottomLeft: 0.1456
#   BottomRight: 0.1768
#   MiddleLeft: 0.3445
#   MiddleRight: 0.2936
#   TopCenter: 0.0003
#   TopLeft: 0.0218
#   TopRight: 0.0143
# [Left Eye] Left: MiddleRight (0.36)
#   BottomCenter: 0.0206
#   BottomLeft: 0.0011
#   BottomRight: 0.1985
#   MiddleLeft: 0.0024
#   MiddleRight: 0.3592
#   TopCenter: 0.0613
#   TopLeft: 0.0048
#   TopRight: 0.3520
# [Right Eye] Right: TopLeft (0.41)
#   BottomCenter: 0.0001
#   BottomLeft: 0.0005
#   BottomRight: 0.0011
#   MiddleLeft: 0.0751
#   MiddleRight: 0.0629
#   TopCenter: 0.0431
#   TopLeft: 0.4150
#   TopRight: 0.4020
# [Left Eye] Left: BottomCenter (0.73)
#   BottomCenter: 0.7297
#   BottomLeft: 0.0212
#   BottomRight: 0.1765
#   MiddleLeft: 0.0029
#   MiddleRight: 0.0232
#   TopCenter: 0.0430
#   TopLeft: 0.0014
#   TopRight: 0.0022
# [Right Eye] Right: TopRight (0.43)
#   BottomCenter: 0.0003
#   BottomLeft: 0.0029
#   BottomRight: 0.0071
#   MiddleLeft: 0.1301
#   MiddleRight: 0.1548
#   TopCenter: 0.0142
#   TopLeft: 0.2615
#   TopRight: 0.4290
# [Left Eye] Left: BottomRight (0.64)
#   BottomCenter: 0.2816
#   BottomLeft: 0.0198
#   BottomRight: 0.6378
#   MiddleLeft: 0.0017
#   MiddleRight: 0.0526
#   TopCenter: 0.0042
#   TopLeft: 0.0004
#   TopRight: 0.0021
# [Right Eye] Right: TopRight (0.46)
#   BottomCenter: 0.0001
#   BottomLeft: 0.0016
#   BottomRight: 0.0039
#   MiddleLeft: 0.1040
#   MiddleRight: 0.1286
#   TopCenter: 0.0078
#   TopLeft: 0.2903
#   TopRight: 0.4636
# [Left Eye] Left: BottomRight (0.28)
#   BottomCenter: 0.0591
#   BottomLeft: 0.1514
#   BottomRight: 0.2836
#   MiddleLeft: 0.1448
#   MiddleRight: 0.2002
#   TopCenter: 0.0223
#   TopLeft: 0.0740
#   TopRight: 0.0647
# [Right Eye] Right: TopRight (0.47)
#   BottomCenter: 0.0001
#   BottomLeft: 0.0031
#   BottomRight: 0.0045
#   MiddleLeft: 0.1037
#   MiddleRight: 0.0915
#   TopCenter: 0.0125
#   TopLeft: 0.3164
#   TopRight: 0.4683
# [Left Eye] Left: BottomRight (0.33)
#   BottomCenter: 0.1280
#   BottomLeft: 0.2943
#   BottomRight: 0.3274
#   MiddleLeft: 0.1108
#   MiddleRight: 0.0854
#   TopCenter: 0.0102
#   TopLeft: 0.0331
#   TopRight: 0.0107
# [Right Eye] Right: MiddleRight (0.24)
#   BottomCenter: 0.0007
#   BottomLeft: 0.0460
#   BottomRight: 0.0945
#   MiddleLeft: 0.1771
#   MiddleRight: 0.2415
#   TopCenter: 0.0111
#   TopLeft: 0.2341
#   TopRight: 0.1950
# [Left Eye] Left: BottomCenter (0.43)
#   BottomCenter: 0.4256
#   BottomLeft: 0.1063
#   BottomRight: 0.0666
#   MiddleLeft: 0.0855
#   MiddleRight: 0.0344
#   TopCenter: 0.2287
#   TopLeft: 0.0465
#   TopRight: 0.0064
# [Right Eye] Right: TopRight (0.43)
#   BottomCenter: 0.0000
#   BottomLeft: 0.0009
#   BottomRight: 0.0050
#   MiddleLeft: 0.0707
#   MiddleRight: 0.1453
#   TopCenter: 0.0069
#   TopLeft: 0.3452
#   TopRight: 0.4260
# [Left Eye] Left: MiddleRight (0.21)
#   BottomCenter: 0.1597
#   BottomLeft: 0.0681
#   BottomRight: 0.1676
#   MiddleLeft: 0.1202
#   MiddleRight: 0.2053
#   TopCenter: 0.1278
#   TopLeft: 0.0923
#   TopRight: 0.0592
# [Right Eye] Right: MiddleRight (0.28)
#   BottomCenter: 0.0001
#   BottomLeft: 0.0071
#   BottomRight: 0.0153
#   MiddleLeft: 0.2511
#   MiddleRight: 0.2797
#   TopCenter: 0.0008
#   TopLeft: 0.1796
#   TopRight: 0.2663
# [Left Eye] Left: BottomRight (0.29)
#   BottomCenter: 0.1996
#   BottomLeft: 0.2697
#   BottomRight: 0.2898
#   MiddleLeft: 0.0998
#   MiddleRight: 0.0769
#   TopCenter: 0.0213
#   TopLeft: 0.0336
#   TopRight: 0.0093
# [Right Eye] Right: TopLeft (0.47)
#   BottomCenter: 0.0002
#   BottomLeft: 0.0051
#   BottomRight: 0.0100
#   MiddleLeft: 0.1024
#   MiddleRight: 0.0876
#   TopCenter: 0.0120
#   TopLeft: 0.4737
#   TopRight: 0.3090
# [Left Eye] Left: BottomRight (0.29)
#   BottomCenter: 0.0348
#   BottomLeft: 0.1825
#   BottomRight: 0.2894
#   MiddleLeft: 0.2038
#   MiddleRight: 0.1876
#   TopCenter: 0.0070
#   TopLeft: 0.0562
#   TopRight: 0.0387
# [Right Eye] Right: TopRight (0.58)
#   BottomCenter: 0.0003
#   BottomLeft: 0.0002
#   BottomRight: 0.0070
#   MiddleLeft: 0.0185
#   MiddleRight: 0.2012
#   TopCenter: 0.0922
#   TopLeft: 0.1055
#   TopRight: 0.5750
# [Left Eye] Left: BottomRight (0.26)
#   BottomCenter: 0.0511
#   BottomLeft: 0.0244
#   BottomRight: 0.2614
#   MiddleLeft: 0.0298
#   MiddleRight: 0.2440
#   TopCenter: 0.1327
#   TopLeft: 0.0389
#   TopRight: 0.2176
# [Right Eye] Right: TopRight (0.55)
#   BottomCenter: 0.0009
#   BottomLeft: 0.0011
#   BottomRight: 0.0121
#   MiddleLeft: 0.0337
#   MiddleRight: 0.1979
#   TopCenter: 0.0729
#   TopLeft: 0.1285
#   TopRight: 0.5529
# [Left Eye] Left: MiddleRight (0.31)
#   BottomCenter: 0.0459
#   BottomLeft: 0.0642
#   BottomRight: 0.2565
#   MiddleLeft: 0.1218
#   MiddleRight: 0.3052
#   TopCenter: 0.0271
#   TopLeft: 0.0660
#   TopRight: 0.1133
# [Right Eye] Right: TopLeft (0.45)
#   BottomCenter: 0.0008
#   BottomLeft: 0.0061
#   BottomRight: 0.0055
#   MiddleLeft: 0.1157
#   MiddleRight: 0.0587
#   TopCenter: 0.0677
#   TopLeft: 0.4549
#   TopRight: 0.2906
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0538
#   BottomLeft: 0.1314
#   BottomRight: 0.1283
#   MiddleLeft: 0.1865
#   MiddleRight: 0.1371
#   TopCenter: 0.0685
#   TopLeft: 0.1780
#   TopRight: 0.1164
# [Right Eye] Right: TopCenter (0.31)
#   BottomCenter: 0.0511
#   BottomLeft: 0.0165
#   BottomRight: 0.0711
#   MiddleLeft: 0.0651
#   MiddleRight: 0.1922
#   TopCenter: 0.3081
#   TopLeft: 0.1405
#   TopRight: 0.1554
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0542
#   BottomLeft: 0.1214
#   BottomRight: 0.1486
#   MiddleLeft: 0.1868
#   MiddleRight: 0.1742
#   TopCenter: 0.0498
#   TopLeft: 0.1388
#   TopRight: 0.1263
# [Right Eye] Right: MiddleLeft (0.34)
#   BottomCenter: 0.0035
#   BottomLeft: 0.0380
#   BottomRight: 0.0515
#   MiddleLeft: 0.3420
#   MiddleRight: 0.2501
#   TopCenter: 0.0103
#   TopLeft: 0.1517
#   TopRight: 0.1530
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0541
#   BottomLeft: 0.1605
#   BottomRight: 0.1612
#   MiddleLeft: 0.1921
#   MiddleRight: 0.1563
#   TopCenter: 0.0420
#   TopLeft: 0.1294
#   TopRight: 0.1044
# [Right Eye] Right: BottomRight (0.19)
#   BottomCenter: 0.1391
#   BottomLeft: 0.1633
#   BottomRight: 0.1946
#   MiddleLeft: 0.1395
#   MiddleRight: 0.1236
#   TopCenter: 0.0940
#   TopLeft: 0.1124
#   TopRight: 0.0335
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0581
#   BottomLeft: 0.1903
#   BottomRight: 0.1458
#   MiddleLeft: 0.2267
#   MiddleRight: 0.1361
#   TopCenter: 0.0363
#   TopLeft: 0.1339
#   TopRight: 0.0728
# [Right Eye] Right: MiddleRight (0.33)
#   BottomCenter: 0.0020
#   BottomLeft: 0.0183
#   BottomRight: 0.0478
#   MiddleLeft: 0.2664
#   MiddleRight: 0.3345
#   TopCenter: 0.0094
#   TopLeft: 0.1234
#   TopRight: 0.1983
# [Right Eye] Right: TopRight (0.19)
#   BottomCenter: 0.0320
#   BottomLeft: 0.0560
#   BottomRight: 0.1119
#   MiddleLeft: 0.1481
#   MiddleRight: 0.1699
#   TopCenter: 0.1042
#   TopLeft: 0.1884
#   TopRight: 0.1895
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0551
#   BottomLeft: 0.1498
#   BottomRight: 0.1498
#   MiddleLeft: 0.2103
#   MiddleRight: 0.1580
#   TopCenter: 0.0423
#   TopLeft: 0.1401
#   TopRight: 0.0946
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0293
#   BottomLeft: 0.1222
#   BottomRight: 0.1145
#   MiddleLeft: 0.2429
#   MiddleRight: 0.1529
#   TopCenter: 0.0367
#   TopLeft: 0.1865
#   TopRight: 0.1151
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0507
#   BottomLeft: 0.1824
#   BottomRight: 0.1298
#   MiddleLeft: 0.2405
#   MiddleRight: 0.1271
#   TopCenter: 0.0404
#   TopLeft: 0.1593
#   TopRight: 0.0698
# [Right Eye] Right: MiddleRight (0.29)
#   BottomCenter: 0.0686
#   BottomLeft: 0.0496
#   BottomRight: 0.2638
#   MiddleLeft: 0.0718
#   MiddleRight: 0.2893
#   TopCenter: 0.0593
#   TopLeft: 0.0525
#   TopRight: 0.1451
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0407
#   BottomLeft: 0.1539
#   BottomRight: 0.1326
#   MiddleLeft: 0.2369
#   MiddleRight: 0.1424
#   TopCenter: 0.0382
#   TopLeft: 0.1661
#   TopRight: 0.0892
# [Left Eye] Left: MiddleLeft (0.26)
#   BottomCenter: 0.0506
#   BottomLeft: 0.1654
#   BottomRight: 0.1202
#   MiddleLeft: 0.2627
#   MiddleRight: 0.1437
#   TopCenter: 0.0311
#   TopLeft: 0.1552
#   TopRight: 0.0711
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0433
#   BottomLeft: 0.1639
#   BottomRight: 0.1509
#   MiddleLeft: 0.2357
#   MiddleRight: 0.1593
#   TopCenter: 0.0315
#   TopLeft: 0.1336
#   TopRight: 0.0819
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0630
#   BottomLeft: 0.1375
#   BottomRight: 0.1342
#   MiddleLeft: 0.1997
#   MiddleRight: 0.1560
#   TopCenter: 0.0533
#   TopLeft: 0.1554
#   TopRight: 0.1010
# [Right Eye] Right: BottomLeft (0.19)
#   BottomCenter: 0.0843
#   BottomLeft: 0.1899
#   BottomRight: 0.1425
#   MiddleLeft: 0.1771
#   MiddleRight: 0.0961
#   TopCenter: 0.0726
#   TopLeft: 0.1604
#   TopRight: 0.0770
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0490
#   BottomLeft: 0.1279
#   BottomRight: 0.1354
#   MiddleLeft: 0.1987
#   MiddleRight: 0.1661
#   TopCenter: 0.0510
#   TopLeft: 0.1487
#   TopRight: 0.1232
# [Right Eye] Right: MiddleRight (0.22)
#   BottomCenter: 0.0440
#   BottomLeft: 0.0670
#   BottomRight: 0.1560
#   MiddleLeft: 0.1571
#   MiddleRight: 0.2185
#   TopCenter: 0.0501
#   TopLeft: 0.1329
#   TopRight: 0.1745
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0518
#   BottomLeft: 0.1500
#   BottomRight: 0.1489
#   MiddleLeft: 0.2026
#   MiddleRight: 0.1642
#   TopCenter: 0.0399
#   TopLeft: 0.1335
#   TopRight: 0.1091
# [Right Eye] Right: BottomRight (0.53)
#   BottomCenter: 0.1406
#   BottomLeft: 0.1090
#   BottomRight: 0.5307
#   MiddleLeft: 0.0431
#   MiddleRight: 0.1081
#   TopCenter: 0.0308
#   TopLeft: 0.0231
#   TopRight: 0.0147
# [Left Eye] Left: BottomRight (0.20)
#   BottomCenter: 0.0565
#   BottomLeft: 0.1569
#   BottomRight: 0.1987
#   MiddleLeft: 0.1738
#   MiddleRight: 0.1759
#   TopCenter: 0.0363
#   TopLeft: 0.1060
#   TopRight: 0.0960
# [Right Eye] Right: BottomLeft (0.33)
#   BottomCenter: 0.0466
#   BottomLeft: 0.3337
#   BottomRight: 0.2542
#   MiddleLeft: 0.1843
#   MiddleRight: 0.1355
#   TopCenter: 0.0032
#   TopLeft: 0.0296
#   TopRight: 0.0127
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0504
#   BottomLeft: 0.1161
#   BottomRight: 0.1371
#   MiddleLeft: 0.1937
#   MiddleRight: 0.1729
#   TopCenter: 0.0540
#   TopLeft: 0.1515
#   TopRight: 0.1243
# [Right Eye] Right: MiddleRight (0.35)
#   BottomCenter: 0.0633
#   BottomLeft: 0.0326
#   BottomRight: 0.2584
#   MiddleLeft: 0.0585
#   MiddleRight: 0.3513
#   TopCenter: 0.0681
#   TopLeft: 0.0491
#   TopRight: 0.1187
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0471
#   BottomLeft: 0.1684
#   BottomRight: 0.1569
#   MiddleLeft: 0.2013
#   MiddleRight: 0.1550
#   TopCenter: 0.0336
#   TopLeft: 0.1329
#   TopRight: 0.1048
# [Right Eye] Right: BottomRight (0.56)
#   BottomCenter: 0.0773
#   BottomLeft: 0.0739
#   BottomRight: 0.5608
#   MiddleLeft: 0.0450
#   MiddleRight: 0.2317
#   TopCenter: 0.0015
#   TopLeft: 0.0050
#   TopRight: 0.0049
# [Left Eye] Left: MiddleRight (0.19)
#   BottomCenter: 0.0479
#   BottomLeft: 0.1340
#   BottomRight: 0.1698
#   MiddleLeft: 0.1808
#   MiddleRight: 0.1851
#   TopCenter: 0.0378
#   TopLeft: 0.1193
#   TopRight: 0.1253
# [Right Eye] Right: BottomRight (0.42)
#   BottomCenter: 0.1503
#   BottomLeft: 0.0245
#   BottomRight: 0.4218
#   MiddleLeft: 0.0244
#   MiddleRight: 0.2743
#   TopCenter: 0.0536
#   TopLeft: 0.0166
#   TopRight: 0.0345
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0513
#   BottomLeft: 0.1745
#   BottomRight: 0.1920
#   MiddleLeft: 0.2062
#   MiddleRight: 0.1766
#   TopCenter: 0.0224
#   TopLeft: 0.0979
#   TopRight: 0.0790
# [Right Eye] Right: BottomCenter (0.68)
#   BottomCenter: 0.6808
#   BottomLeft: 0.0306
#   BottomRight: 0.1878
#   MiddleLeft: 0.0039
#   MiddleRight: 0.0319
#   TopCenter: 0.0590
#   TopLeft: 0.0032
#   TopRight: 0.0028
# [Left Eye] Left: MiddleRight (0.19)
#   BottomCenter: 0.0607
#   BottomLeft: 0.1290
#   BottomRight: 0.1866
#   MiddleLeft: 0.1792
#   MiddleRight: 0.1884
#   TopCenter: 0.0391
#   TopLeft: 0.1104
#   TopRight: 0.1066
# [Right Eye] Right: TopRight (0.19)
#   BottomCenter: 0.0476
#   BottomLeft: 0.0593
#   BottomRight: 0.1190
#   MiddleLeft: 0.1447
#   MiddleRight: 0.1844
#   TopCenter: 0.1040
#   TopLeft: 0.1540
#   TopRight: 0.1870
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0443
#   BottomLeft: 0.1427
#   BottomRight: 0.1634
#   MiddleLeft: 0.2037
#   MiddleRight: 0.1813
#   TopCenter: 0.0294
#   TopLeft: 0.1220
#   TopRight: 0.1132
# [Right Eye] Right: MiddleRight (0.24)
#   BottomCenter: 0.0605
#   BottomLeft: 0.0653
#   BottomRight: 0.2204
#   MiddleLeft: 0.1102
#   MiddleRight: 0.2443
#   TopCenter: 0.0602
#   TopLeft: 0.0889
#   TopRight: 0.1501
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0539
#   BottomLeft: 0.1440
#   BottomRight: 0.1828
#   MiddleLeft: 0.1918
#   MiddleRight: 0.1836
#   TopCenter: 0.0320
#   TopLeft: 0.1107
#   TopRight: 0.1012
# [Right Eye] Right: MiddleRight (0.19)
#   BottomCenter: 0.0453
#   BottomLeft: 0.1011
#   BottomRight: 0.1504
#   MiddleLeft: 0.1807
#   MiddleRight: 0.1950
#   TopCenter: 0.0473
#   TopLeft: 0.1363
#   TopRight: 0.1439
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0566
#   BottomLeft: 0.1259
#   BottomRight: 0.1643
#   MiddleLeft: 0.1828
#   MiddleRight: 0.1819
#   TopCenter: 0.0447
#   TopLeft: 0.1248
#   TopRight: 0.1189
# [Right Eye] Right: MiddleRight (0.20)
#   BottomCenter: 0.0501
#   BottomLeft: 0.0995
#   BottomRight: 0.1610
#   MiddleLeft: 0.1716
#   MiddleRight: 0.1959
#   TopCenter: 0.0529
#   TopLeft: 0.1293
#   TopRight: 0.1398
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0550
#   BottomLeft: 0.1398
#   BottomRight: 0.1576
#   MiddleLeft: 0.1936
#   MiddleRight: 0.1663
#   TopCenter: 0.0443
#   TopLeft: 0.1361
#   TopRight: 0.1073
# [Right Eye] Right: BottomRight (0.28)
#   BottomCenter: 0.1147
#   BottomLeft: 0.1015
#   BottomRight: 0.2841
#   MiddleLeft: 0.0721
#   MiddleRight: 0.1358
#   TopCenter: 0.1311
#   TopLeft: 0.0898
#   TopRight: 0.0709
# [Left Eye] Left: BottomRight (0.18)
#   BottomCenter: 0.0715
#   BottomLeft: 0.1470
#   BottomRight: 0.1751
#   MiddleLeft: 0.1726
#   MiddleRight: 0.1681
#   TopCenter: 0.0479
#   TopLeft: 0.1146
#   TopRight: 0.1032
# [Right Eye] Right: BottomRight (0.35)
#   BottomCenter: 0.1378
#   BottomLeft: 0.0171
#   BottomRight: 0.3512
#   MiddleLeft: 0.0086
#   MiddleRight: 0.1141
#   TopCenter: 0.2877
#   TopLeft: 0.0235
#   TopRight: 0.0599
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0570
#   BottomLeft: 0.1330
#   BottomRight: 0.1347
#   MiddleLeft: 0.1940
#   MiddleRight: 0.1521
#   TopCenter: 0.0564
#   TopLeft: 0.1535
#   TopRight: 0.1192
# [Right Eye] Right: BottomRight (0.43)
#   BottomCenter: 0.1141
#   BottomLeft: 0.0660
#   BottomRight: 0.4320
#   MiddleLeft: 0.0538
#   MiddleRight: 0.2911
#   TopCenter: 0.0090
#   TopLeft: 0.0156
#   TopRight: 0.0184
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0508
#   BottomLeft: 0.1237
#   BottomRight: 0.1423
#   MiddleLeft: 0.1946
#   MiddleRight: 0.1705
#   TopCenter: 0.0491
#   TopLeft: 0.1466
#   TopRight: 0.1225
# [Right Eye] Right: BottomRight (0.25)
#   BottomCenter: 0.0695
#   BottomLeft: 0.1487
#   BottomRight: 0.2540
#   MiddleLeft: 0.1222
#   MiddleRight: 0.1359
#   TopCenter: 0.0666
#   TopLeft: 0.1222
#   TopRight: 0.0808
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0507
#   BottomLeft: 0.1582
#   BottomRight: 0.1185
#   MiddleLeft: 0.2314
#   MiddleRight: 0.1357
#   TopCenter: 0.0471
#   TopLeft: 0.1595
#   TopRight: 0.0990
# [Right Eye] Right: MiddleRight (0.19)
#   BottomCenter: 0.0503
#   BottomLeft: 0.0903
#   BottomRight: 0.1295
#   MiddleLeft: 0.1831
#   MiddleRight: 0.1881
#   TopCenter: 0.0620
#   TopLeft: 0.1544
#   TopRight: 0.1424
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0690
#   BottomLeft: 0.1381
#   BottomRight: 0.1671
#   MiddleLeft: 0.1840
#   MiddleRight: 0.1750
#   TopCenter: 0.0495
#   TopLeft: 0.1207
#   TopRight: 0.0965
# [Right Eye] Right: MiddleRight (0.17)
#   BottomCenter: 0.0754
#   BottomLeft: 0.1001
#   BottomRight: 0.1404
#   MiddleLeft: 0.1604
#   MiddleRight: 0.1682
#   TopCenter: 0.0806
#   TopLeft: 0.1489
#   TopRight: 0.1260
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0670
#   BottomLeft: 0.1552
#   BottomRight: 0.1615
#   MiddleLeft: 0.2014
#   MiddleRight: 0.1597
#   TopCenter: 0.0466
#   TopLeft: 0.1253
#   TopRight: 0.0832
# [Right Eye] Right: MiddleLeft (0.19)
#   BottomCenter: 0.0631
#   BottomLeft: 0.1327
#   BottomRight: 0.1581
#   MiddleLeft: 0.1927
#   MiddleRight: 0.1637
#   TopCenter: 0.0478
#   TopLeft: 0.1366
#   TopRight: 0.1053
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0757
#   BottomLeft: 0.1665
#   BottomRight: 0.1763
#   MiddleLeft: 0.1943
#   MiddleRight: 0.1558
#   TopCenter: 0.0452
#   TopLeft: 0.1157
#   TopRight: 0.0706
# [Right Eye] Right: MiddleRight (0.19)
#   BottomCenter: 0.0613
#   BottomLeft: 0.1012
#   BottomRight: 0.1677
#   MiddleLeft: 0.1682
#   MiddleRight: 0.1895
#   TopCenter: 0.0568
#   TopLeft: 0.1286
#   TopRight: 0.1266
# [Left Eye] Left: MiddleLeft (0.24)
#   BottomCenter: 0.0605
#   BottomLeft: 0.1920
#   BottomRight: 0.1260
#   MiddleLeft: 0.2413
#   MiddleRight: 0.1239
#   TopCenter: 0.0415
#   TopLeft: 0.1463
#   TopRight: 0.0685
# [Right Eye] Right: MiddleLeft (0.19)
#   BottomCenter: 0.0616
#   BottomLeft: 0.1193
#   BottomRight: 0.1375
#   MiddleLeft: 0.1897
#   MiddleRight: 0.1518
#   TopCenter: 0.0708
#   TopLeft: 0.1546
#   TopRight: 0.1146
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0382
#   BottomLeft: 0.1307
#   BottomRight: 0.1327
#   MiddleLeft: 0.2292
#   MiddleRight: 0.1685
#   TopCenter: 0.0346
#   TopLeft: 0.1520
#   TopRight: 0.1139
# [Right Eye] Right: MiddleLeft (0.18)
#   BottomCenter: 0.0542
#   BottomLeft: 0.1276
#   BottomRight: 0.1481
#   MiddleLeft: 0.1791
#   MiddleRight: 0.1659
#   TopCenter: 0.0459
#   TopLeft: 0.1492
#   TopRight: 0.1299
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0621
#   BottomLeft: 0.1314
#   BottomRight: 0.1600
#   MiddleLeft: 0.1847
#   MiddleRight: 0.1714
#   TopCenter: 0.0483
#   TopLeft: 0.1281
#   TopRight: 0.1140
# [Right Eye] Right: BottomRight (0.49)
#   BottomCenter: 0.1561
#   BottomLeft: 0.0190
#   BottomRight: 0.4901
#   MiddleLeft: 0.0084
#   MiddleRight: 0.2061
#   TopCenter: 0.0550
#   TopLeft: 0.0111
#   TopRight: 0.0541
# [Right Eye] Right: MiddleRight (0.20)
#   BottomCenter: 0.0539
#   BottomLeft: 0.1056
#   BottomRight: 0.1547
#   MiddleLeft: 0.1636
#   MiddleRight: 0.1997
#   TopCenter: 0.0491
#   TopLeft: 0.1355
#   TopRight: 0.1380
# [Right Eye] Right: MiddleRight (0.21)
#   BottomCenter: 0.0504
#   BottomLeft: 0.0824
#   BottomRight: 0.1443
#   MiddleLeft: 0.1541
#   MiddleRight: 0.2131
#   TopCenter: 0.0566
#   TopLeft: 0.1407
#   TopRight: 0.1584
# [Right Eye] Right: MiddleRight (0.21)
#   BottomCenter: 0.0353
#   BottomLeft: 0.0867
#   BottomRight: 0.1289
#   MiddleLeft: 0.1865
#   MiddleRight: 0.2051
#   TopCenter: 0.0420
#   TopLeft: 0.1651
#   TopRight: 0.1504
# [Left Eye] Left: MiddleLeft (0.25)
#   BottomCenter: 0.0431
#   BottomLeft: 0.1622
#   BottomRight: 0.1259
#   MiddleLeft: 0.2487
#   MiddleRight: 0.1443
#   TopCenter: 0.0335
#   TopLeft: 0.1557
#   TopRight: 0.0866
# [Right Eye] Right: BottomRight (0.18)
#   BottomCenter: 0.1009
#   BottomLeft: 0.1635
#   BottomRight: 0.1769
#   MiddleLeft: 0.1560
#   MiddleRight: 0.1359
#   TopCenter: 0.0810
#   TopLeft: 0.1459
#   TopRight: 0.0398
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0476
#   BottomLeft: 0.1064
#   BottomRight: 0.1332
#   MiddleLeft: 0.1888
#   MiddleRight: 0.1765
#   TopCenter: 0.0535
#   TopLeft: 0.1536
#   TopRight: 0.1405
# [Right Eye] Right: BottomRight (0.23)
#   BottomCenter: 0.2256
#   BottomLeft: 0.0300
#   BottomRight: 0.2337
#   MiddleLeft: 0.0298
#   MiddleRight: 0.2079
#   TopCenter: 0.1638
#   TopLeft: 0.0391
#   TopRight: 0.0701
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0577
#   BottomLeft: 0.1754
#   BottomRight: 0.1546
#   MiddleLeft: 0.2123
#   MiddleRight: 0.1423
#   TopCenter: 0.0387
#   TopLeft: 0.1329
#   TopRight: 0.0861
# [Right Eye] Right: TopCenter (0.28)
#   BottomCenter: 0.0913
#   BottomLeft: 0.1064
#   BottomRight: 0.0529
#   MiddleLeft: 0.1628
#   MiddleRight: 0.0520
#   TopCenter: 0.2807
#   TopLeft: 0.2241
#   TopRight: 0.0298
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0374
#   BottomLeft: 0.1231
#   BottomRight: 0.1438
#   MiddleLeft: 0.2112
#   MiddleRight: 0.1791
#   TopCenter: 0.0349
#   TopLeft: 0.1408
#   TopRight: 0.1298
# [Right Eye] Right: BottomRight (0.18)
#   BottomCenter: 0.1755
#   BottomLeft: 0.1712
#   BottomRight: 0.1761
#   MiddleLeft: 0.1422
#   MiddleRight: 0.1150
#   TopCenter: 0.0843
#   TopLeft: 0.1081
#   TopRight: 0.0276
# [Left Eye] Left: MiddleLeft (0.22)
#   BottomCenter: 0.0485
#   BottomLeft: 0.1628
#   BottomRight: 0.1310
#   MiddleLeft: 0.2232
#   MiddleRight: 0.1427
#   TopCenter: 0.0416
#   TopLeft: 0.1538
#   TopRight: 0.0963
# [Right Eye] Right: MiddleRight (0.59)
#   BottomCenter: 0.0128
#   BottomLeft: 0.0066
#   BottomRight: 0.3004
#   MiddleLeft: 0.0217
#   MiddleRight: 0.5908
#   TopCenter: 0.0042
#   TopLeft: 0.0067
#   TopRight: 0.0568
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0523
#   BottomLeft: 0.1227
#   BottomRight: 0.1509
#   MiddleLeft: 0.1893
#   MiddleRight: 0.1815
#   TopCenter: 0.0450
#   TopLeft: 0.1337
#   TopRight: 0.1246
# [Right Eye] Right: MiddleRight (0.33)
#   BottomCenter: 0.0286
#   BottomLeft: 0.0647
#   BottomRight: 0.2159
#   MiddleLeft: 0.1468
#   MiddleRight: 0.3329
#   TopCenter: 0.0311
#   TopLeft: 0.0835
#   TopRight: 0.0964
# [Left Eye] Left: MiddleRight (0.18)
#   BottomCenter: 0.0584
#   BottomLeft: 0.1319
#   BottomRight: 0.1735
#   MiddleLeft: 0.1778
#   MiddleRight: 0.1828
#   TopCenter: 0.0411
#   TopLeft: 0.1187
#   TopRight: 0.1158
# [Right Eye] Right: BottomLeft (0.40)
#   BottomCenter: 0.0225
#   BottomLeft: 0.3988
#   BottomRight: 0.1924
#   MiddleLeft: 0.2765
#   MiddleRight: 0.0876
#   TopCenter: 0.0004
#   TopLeft: 0.0205
#   TopRight: 0.0012
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0484
#   BottomLeft: 0.1679
#   BottomRight: 0.1327
#   MiddleLeft: 0.2336
#   MiddleRight: 0.1408
#   TopCenter: 0.0372
#   TopLeft: 0.1532
#   TopRight: 0.0863
# [Right Eye] Right: MiddleRight (0.56)
#   BottomCenter: 0.0142
#   BottomLeft: 0.0042
#   BottomRight: 0.2011
#   MiddleLeft: 0.0182
#   MiddleRight: 0.5598
#   TopCenter: 0.0174
#   TopLeft: 0.0147
#   TopRight: 0.1705
# [Left Eye] Left: MiddleLeft (0.23)
#   BottomCenter: 0.0398
#   BottomLeft: 0.1595
#   BottomRight: 0.1349
#   MiddleLeft: 0.2280
#   MiddleRight: 0.1436
#   TopCenter: 0.0364
#   TopLeft: 0.1642
#   TopRight: 0.0936
# [Right Eye] Right: TopLeft (0.30)
#   BottomCenter: 0.0267
#   BottomLeft: 0.0179
#   BottomRight: 0.0373
#   MiddleLeft: 0.1878
#   MiddleRight: 0.2106
#   TopCenter: 0.1069
#   TopLeft: 0.3038
#   TopRight: 0.1090
# [Left Eye] Left: MiddleLeft (0.19)
#   BottomCenter: 0.0554
#   BottomLeft: 0.1276
#   BottomRight: 0.1594
#   MiddleLeft: 0.1865
#   MiddleRight: 0.1802
#   TopCenter: 0.0437
#   TopLeft: 0.1294
#   TopRight: 0.1177
# [Right Eye] Right: BottomRight (0.32)
#   BottomCenter: 0.1936
#   BottomLeft: 0.0447
#   BottomRight: 0.3220
#   MiddleLeft: 0.0284
#   MiddleRight: 0.2101
#   TopCenter: 0.1086
#   TopLeft: 0.0307
#   TopRight: 0.0620
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0731
#   BottomLeft: 0.1842
#   BottomRight: 0.1879
#   MiddleLeft: 0.1638
#   MiddleRight: 0.1423
#   TopCenter: 0.0468
#   TopLeft: 0.1143
#   TopRight: 0.0877
# [Right Eye] Right: BottomRight (0.42)
#   BottomCenter: 0.3123
#   BottomLeft: 0.1478
#   BottomRight: 0.4212
#   MiddleLeft: 0.0121
#   MiddleRight: 0.0679
#   TopCenter: 0.0194
#   TopLeft: 0.0123
#   TopRight: 0.0071
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0679
#   BottomLeft: 0.1483
#   BottomRight: 0.1670
#   MiddleLeft: 0.1755
#   MiddleRight: 0.1644
#   TopCenter: 0.0530
#   TopLeft: 0.1226
#   TopRight: 0.1012
# [Right Eye] Right: MiddleRight (0.20)
#   BottomCenter: 0.0376
#   BottomLeft: 0.0904
#   BottomRight: 0.1152
#   MiddleLeft: 0.1926
#   MiddleRight: 0.1980
#   TopCenter: 0.0437
#   TopLeft: 0.1673
#   TopRight: 0.1553
# [Left Eye] Left: MiddleLeft (0.21)
#   BottomCenter: 0.0481
#   BottomLeft: 0.1445
#   BottomRight: 0.1560
#   MiddleLeft: 0.2057
#   MiddleRight: 0.1690
#   TopCenter: 0.0433
#   TopLeft: 0.1396
#   TopRight: 0.0938
# [Right Eye] Right: MiddleRight (0.31)
#   BottomCenter: 0.1317
#   BottomLeft: 0.0274
#   BottomRight: 0.2934
#   MiddleLeft: 0.0323
#   MiddleRight: 0.3075
#   TopCenter: 0.0677
#   TopLeft: 0.0300
#   TopRight: 0.1100
# [Left Eye] Left: BottomRight (0.30)
#   BottomCenter: 0.1120
#   BottomLeft: 0.1565
#   BottomRight: 0.2954
#   MiddleLeft: 0.1051
#   MiddleRight: 0.1836
#   TopCenter: 0.0336
#   TopLeft: 0.0535
#   TopRight: 0.0603
# [Right Eye] Right: TopLeft (0.18)
#   BottomCenter: 0.1021
#   BottomLeft: 0.1156
#   BottomRight: 0.1512
#   MiddleLeft: 0.1377
#   MiddleRight: 0.1310
#   TopCenter: 0.1076
#   TopLeft: 0.1791
#   TopRight: 0.0758
# [Left Eye] Left: MiddleRight (0.20)
#   BottomCenter: 0.0311
#   BottomLeft: 0.1114
#   BottomRight: 0.1395
#   MiddleLeft: 0.2022
#   MiddleRight: 0.2032
#   TopCenter: 0.0336
#   TopLeft: 0.1356
#   TopRight: 0.1434
# [Right Eye] Right: BottomRight (0.25)
#   BottomCenter: 0.1007
#   BottomLeft: 0.1761
#   BottomRight: 0.2474
#   MiddleLeft: 0.0975
#   MiddleRight: 0.1898
#   TopCenter: 0.0503
#   TopLeft: 0.0878
#   TopRight: 0.0502
# [Left Eye] Left: MiddleRight (0.19)
#   BottomCenter: 0.0715
#   BottomLeft: 0.1116
#   BottomRight: 0.1712
#   MiddleLeft: 0.1435
#   MiddleRight: 0.1941
#   TopCenter: 0.0548
#   TopLeft: 0.1183
#   TopRight: 0.1348
# [Right Eye] Right: BottomRight (0.48)
#   BottomCenter: 0.1650
#   BottomLeft: 0.1219
#   BottomRight: 0.4779
#   MiddleLeft: 0.0354
#   MiddleRight: 0.1102
#   TopCenter: 0.0471
#   TopLeft: 0.0257
#   TopRight: 0.0167
# [Left Eye] Left: MiddleRight (0.18)
#   BottomCenter: 0.0652
#   BottomLeft: 0.1318
#   BottomRight: 0.1619
#   MiddleLeft: 0.1696
#   MiddleRight: 0.1762
#   TopCenter: 0.0454
#   TopLeft: 0.1239
#   TopRight: 0.1261
# [Right Eye] Right: BottomCenter (0.39)
#   BottomCenter: 0.3882
#   BottomLeft: 0.3272
#   BottomRight: 0.0325
#   MiddleLeft: 0.1154
#   MiddleRight: 0.0167
#   TopCenter: 0.0408
#   TopLeft: 0.0779
#   TopRight: 0.0013
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0590
#   BottomLeft: 0.1593
#   BottomRight: 0.1945
#   MiddleLeft: 0.1749
#   MiddleRight: 0.1859
#   TopCenter: 0.0281
#   TopLeft: 0.0959
#   TopRight: 0.1024
# [Right Eye] Right: TopLeft (0.29)
#   BottomCenter: 0.0128
#   BottomLeft: 0.0208
#   BottomRight: 0.0461
#   MiddleLeft: 0.1667
#   MiddleRight: 0.2080
#   TopCenter: 0.0897
#   TopLeft: 0.2924
#   TopRight: 0.1635
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0689
#   BottomLeft: 0.1661
#   BottomRight: 0.1668
#   MiddleLeft: 0.1800
#   MiddleRight: 0.1490
#   TopCenter: 0.0471
#   TopLeft: 0.1303
#   TopRight: 0.0919
# [Right Eye] Right: BottomRight (0.20)
#   BottomCenter: 0.1644
#   BottomLeft: 0.1537
#   BottomRight: 0.2042
#   MiddleLeft: 0.1496
#   MiddleRight: 0.1252
#   TopCenter: 0.0872
#   TopLeft: 0.0941
#   TopRight: 0.0215
# [Left Eye] Left: MiddleRight (0.20)
#   BottomCenter: 0.0426
#   BottomLeft: 0.1241
#   BottomRight: 0.1518
#   MiddleLeft: 0.1831
#   MiddleRight: 0.1987
#   TopCenter: 0.0365
#   TopLeft: 0.1218
#   TopRight: 0.1415
# [Right Eye] Right: BottomCenter (0.37)
#   BottomCenter: 0.3695
#   BottomLeft: 0.0091
#   BottomRight: 0.2889
#   MiddleLeft: 0.0031
#   MiddleRight: 0.1308
#   TopCenter: 0.1706
#   TopLeft: 0.0046
#   TopRight: 0.0233
# [Left Eye] Left: MiddleRight (0.18)
#   BottomCenter: 0.0563
#   BottomLeft: 0.1248
#   BottomRight: 0.1617
#   MiddleLeft: 0.1702
#   MiddleRight: 0.1802
#   TopCenter: 0.0477
#   TopLeft: 0.1331
#   TopRight: 0.1260
# [Right Eye] Right: BottomLeft (0.82)
#   BottomCenter: 0.0148
#   BottomLeft: 0.8200
#   BottomRight: 0.0568
#   MiddleLeft: 0.0995
#   MiddleRight: 0.0079
#   TopCenter: 0.0000
#   TopLeft: 0.0011
#   TopRight: 0.0000
# [Left Eye] Left: BottomRight (0.19)
#   BottomCenter: 0.0662
#   BottomLeft: 0.1407
#   BottomRight: 0.1874
#   MiddleLeft: 0.1707
#   MiddleRight: 0.1867
#   TopCenter: 0.0392
#   TopLeft: 0.1027
#   TopRight: 0.1064
# [Right Eye] Right: BottomRight (0.34)
#   BottomCenter: 0.1079
#   BottomLeft: 0.1017
#   BottomRight: 0.3447
#   MiddleLeft: 0.0796
#   MiddleRight: 0.2723
#   TopCenter: 0.0197
#   TopLeft: 0.0400
#   TopRight: 0.0342
# [Left Eye] Left: BottomRight (0.17)
#   BottomCenter: 0.0749
#   BottomLeft: 0.1608
#   BottomRight: 0.1674
#   MiddleLeft: 0.1631
#   MiddleRight: 0.1514
#   TopCenter: 0.0530
#   TopLeft: 0.1189
#   TopRight: 0.1105
# [Right Eye] Right: BottomRight (0.53)
#   BottomCenter: 0.0706
#   BottomLeft: 0.2766
#   BottomRight: 0.5288
#   MiddleLeft: 0.0459
#   MiddleRight: 0.0711
#   TopCenter: 0.0011
#   TopLeft: 0.0044
#   TopRight: 0.0016
# [Left Eye] Left: BottomRight (0.20)
#   BottomCenter: 0.1011
#   BottomLeft: 0.1774
#   BottomRight: 0.1953
#   MiddleLeft: 0.1424
#   MiddleRight: 0.1467
#   TopCenter: 0.0625
#   TopLeft: 0.1013
#   TopRight: 0.0733
# [Right Eye] Right: BottomLeft (0.42)
#   BottomCenter: 0.0403
#   BottomLeft: 0.4219
#   BottomRight: 0.2840
#   MiddleLeft: 0.1426
#   MiddleRight: 0.1039
#   TopCenter: 0.0003
#   TopLeft: 0.0054
#   TopRight: 0.0015
# [Left Eye] Left: MiddleLeft (0.18)
#   BottomCenter: 0.0634
#   BottomLeft: 0.1477
#   BottomRight: 0.1679
#   MiddleLeft: 0.1788
#   MiddleRight: 0.1638
#   TopCenter: 0.0514
#   TopLeft: 0.1224
#   TopRight: 0.1047
# [Right Eye] Right: TopRight (0.41)
#   BottomCenter: 0.0192
#   BottomLeft: 0.0060
#   BottomRight: 0.0715
#   MiddleLeft: 0.0341
#   MiddleRight: 0.2658
#   TopCenter: 0.1291
#   TopLeft: 0.0656
#   TopRight: 0.4088
# [Left Eye] Left: MiddleLeft (0.20)
#   BottomCenter: 0.0516
#   BottomLeft: 0.1707
#   BottomRight: 0.1491
#   MiddleLeft: 0.2033
#   MiddleRight: 0.1522
#   TopCenter: 0.0393
#   TopLeft: 0.1330
#   TopRight: 0.1009
# [Right Eye] Right: BottomLeft (0.29)
#   BottomCenter: 0.1866
#   BottomLeft: 0.2938
#   BottomRight: 0.1623
#   MiddleLeft: 0.1449
#   MiddleRight: 0.0617
#   TopCenter: 0.0694
#   TopLeft: 0.0686
#   TopRight: 0.0127
